# %% [markdown]
# # Synthetic Data Generation

# %% [markdown]
# ## Introduction
#
# We will be generating 3 types of dataset:
# * Duplicates: where a sleected number of documents will be very similar to others without being a copy paste (paraphrasing)
# * Synergy: there will be 2 documents that will be key to answer the questions. If any of the 2 docs. is missing the LLM will not be able to answer.
# * Complementary: there are 2 documents that will each offer a part of the answer to the question.
#
# Each dataset will have 10 samples, each composed of 1 question, 10 documents (context), 1 answer. The "positive" documents will be marked by the letters: A & B (sort of id).

# %% [markdown]
# ## Imports and Setup

# %%
import pandas as pd
import string
import numpy as np

# %% [markdown]
# ### Utils

# %%
def create_id(df : pd.DataFrame) -> pd.DataFrame: 
    letters = list(string.ascii_uppercase[: len(df.context.loc[0])])
    df["id"] = np.vstack([letters]*df.shape[0]).tolist()
    return df

# %% [markdown]
# ## Data Generation

# %% [markdown]
# ### Duplicated Dataset

# %% [markdown]
# #### Generation

# %%
data = [
    {
        "question": "What is the primary function of a Zylosian Geo-Resonator?",
        "context": [
            # Golden Document 1
            "The main function of a Zylosian Geo-Resonator is to emit a harmonic wave that stabilizes volatile Chronium deposits during mining.",
            # Golden Document 2
            "A Zylosian Geo-Resonator is used primarily to stabilize highly reactive Chronium deposits by generating a low-frequency harmonic wave.",
            # Distractor Documents
            "The Zylosian Geo-Resonator model XR-7A requires a standard Z-type power cell to operate.",
            "Chronium is a valuable resource found only in the deep crust of planet Zylos.",
            "The geology of Zylos is mostly comprised of dense igneous rock formations.",
            "Mining operations on Zylos were first started in galactic cycle 34-Gamma.",
            "Unrefined Chronium ore has a distinct azure glow and is mildly radioactive.",
            "The native fauna of Zylos, such as the Gleebs, are unaffected by Chronium.",
            "Safety protocols mandate that all personnel wear radiation-shielded gear near a Geo-Resonator.",
            "The market price of Chronium has increased by 15% in the last quarter."
        ],
        "answer": "The primary function of a Zylosian Geo-Resonator is to stabilize volatile Chronium deposits using a harmonic wave."
    },
    {
        "question": "Why was the Q3 launch of Project Nebula at Vortex Corp postponed?",
        "context": [
            # Golden Document 1
            "Project Nebula's launch was postponed because of a major security flaw discovered in the authentication module of the QuantumLeap framework.",
            # Golden Document 2
            "The delay of Project Nebula's launch was caused by the discovery of a critical security vulnerability within the QuantumLeap framework's authentication system.",
            # Distractor Documents
            "Project Nebula is Vortex Corp's next-generation data analytics platform.",
            "The QuantumLeap framework is a proprietary technology developed by Vortex Corp.",
            "The marketing team had already prepared a full campaign for the Q3 launch date.",
            "Team members on Project Nebula will now focus on bug-fixing sprints.",
            "Vortex Corp's stock price saw a minor dip following the announcement.",
            "Project Chimera, another initiative at Vortex Corp, is reportedly ahead of schedule.",
            "The user interface for Project Nebula has received positive feedback from early testers.",
            "The budget for Project Nebula in Q4 will be increased to cover delay costs."
        ],
        "answer": "The Q3 launch of Project Nebula was postponed due to a critical security flaw or vulnerability discovered in the authentication module of the QuantumLeap framework."
    },
    {
        "question": "What happens to Sunstone Amulets when they are brought into the Shadow Fen?",
        "context": [
            # Golden Document 1
            "When a Sunstone Amulet is brought into the Shadow Fen, its magical energy is completely nullified by the region's ambient dark magic.",
            # Golden Document 2
            "A Sunstone Amulet loses all of its power upon entering the Shadow Fen, as the area's pervasive necrotic energies drain it entirely.",
            # Distractor Documents
            "Sunstone Amulets are crafted from petrified sunlight and woven with silver threads.",
            "The Shadow Fen is a vast, magical swamp on the southern border of Aethelgard.",
            "To recharge a Sunstone Amulet, it must be left in direct sunlight.",
            "Other magical items, like the Shield of Dawn, are resistant to the Fen's magic.",
            "The last king of Aethelgard was said to have been lost in the Shadow Fen.",
            "The flora in the Shadow Fen includes the dangerous 'Grasping Vine' plant.",
            "Crafting a Sunstone Amulet requires a complex incantation known only to mages.",
            "The amulets are a symbol of the Aethelgardian royal family."
        ],
        "answer": "When Sunstone Amulets are brought into the Shadow Fen, their power is completely drained or nullified by the area's dark magic."
    },
    {
        "question": "What is the sole food source for the Glimmerwing Moths of Aeridor?",
        "context": [
            # Golden Document 1
            "The diet of the Glimmerwing Moth is highly specialized, as it feeds exclusively on the pollen of the nocturnal Moonsilk Flower.",
            # Golden Document 2
            "The only substance that Glimmerwing Moths consume for sustenance is the pollen from the Moonsilk Flower, a rare bloom.",
            # Distractor Documents
            "Glimmerwing Moths are found only in the Crystal Spires region of Aeridor.",
            "The wings of a Glimmerwing Moth are prized for their iridescent dust.",
            "The Moonsilk Flower only blooms during a full moon on Aeridor.",
            "Aeridor is also home to the Stone-Hide Wyvern, a natural predator of the moth.",
            "The lifespan of a Glimmerwing Moth is a single lunar cycle.",
            "Many attempts to cultivate the Moonsilk Flower outside of Aeridor have failed.",
            "The larval stage of the Glimmerwing Moth lives inside crystalline structures.",
            "The Crystal Spires are giant, translucent mountains that hum with energy."
        ],
        "answer": "The sole food source for the Glimmerwing Moths of Aeridor is the pollen of the Moonsilk Flower."
    },
    {
        "question": "According to the Lumina Accords, what is the designated purpose of 'quiet zones'?",
        "context": [
            # Golden Document 1
            "The designated purpose of 'quiet zones' in shared habitats is to provide a sensory-neutral space for species with hypersensitive abilities.",
            # Golden Document 2
            "'Quiet zones' are specifically meant to serve as a refuge for inhabitants who possess heightened sensory faculties, like telepathy or acute hearing.",
            # Distractor Documents
            "The Lumina Accords were signed after a conflict between two major federations.",
            "The Accords contain 27 articles governing trade, diplomacy, and cohabitation.",
            "The Cygnans are a non-verbal, telepathic species covered by the Accords.",
            "Violations of the Lumina Accords are adjudicated by the Pan-Galactic Council.",
            "Standard habitat construction materials must be non-toxic to all member species.",
            "Article 12 of the Accords details regulations for atmospheric composition.",
            "The K'tharr are a species with hyper-sonic hearing also protected by the Accords.",
            "Each shared habitat must have its charter ratified by an Accords representative."
        ],
        "answer": "The designated purpose of 'quiet zones' is to provide a sensory-neutral space or refuge for species with hypersensitive abilities."
    },
    {
        "question": "What material is the 'Pylon of Ozym' made from?",
        "context": [
            # Golden Document 1
            "Analysis confirms the Pylon of Ozym is not made of any known metal but is composed entirely of solidified, hyper-dense neutrino-ium.",
            # Golden Document 2
            "Deep-scan results are conclusive: the Pylon of Ozym is constructed from a seamless piece of solidified neutrino-ium.",
            # Distractor Documents
            "The Pylon of Ozym is a large monolith located in the center of the San-Grel desert.",
            "The Pylon stands exactly 1,337 meters tall and emits a low, constant hum.",
            "Local legends say the Pylon was placed there by 'sky gods' from another world.",
            "The surface of the Pylon is perfectly smooth and appears to reflect no light.",
            "Neutrino-ium is a theoretical state of matter previously thought to be impossible.",
            "Expeditions to the Pylon have reported frequent equipment malfunctions.",
            "The name 'Ozym' is a local tribal word that means 'eternal' or 'unwavering'.",
            "No known tool or weapon has ever been able to scratch the Pylon's surface."
        ],
        "answer": "The Pylon of Ozym is made from solidified, hyper-dense neutrino-ium."
    },
    {
        "question": "In the programming language CortexScript, what does the '->>' operator do?",
        "context": [
            # Golden Document 1
            "In CortexScript, the '->>' operator is used to channel the output of one asynchronous 'Cognate' function directly into another.",
            # Golden Document 2
            "The purpose of the '->>' operator in CortexScript is to pipe the results from one asynchronous 'Cognate' into the next one in a pipeline.",
            # Distractor Documents
            "CortexScript is a language designed for interfacing with neural network APIs.",
            "A 'Cognate' in CortexScript is a special type of asynchronous generator function.",
            "The standard assignment operator in CortexScript is ':=', not the more common '='.",
            "Error handling in CortexScript is managed through 'try...except' blocks.",
            "Version 3.0 of CortexScript introduced major performance improvements.",
            "The '=>' operator in the language is used for defining anonymous lambda functions.",
            "CortexScript was developed by the AI research firm Neuromancer Labs.",
            "Variables in CortexScript are declared using the 'let' keyword."
        ],
        "answer": "The '->>' operator is used to channel or pipe the output of one asynchronous 'Cognate' function into another."
    },
    {
        "question": "What is the cause of Hyper-Chrono Displacement in 'Warp-Slinger' pilots?",
        "context": [
            # Golden Document 1
            "Hyper-Chrono Displacement is a condition caused by prolonged exposure to temporal fluctuations from the ship's 'Reality Anchor' during FTL travel.",
            # Golden Document 2
            "The cause of Hyper-Chrono Displacement in pilots is long-term exposure to the small temporal waves generated by a 'Warp-Slinger's' Reality Anchor.",
            # Distractor Documents
            "'Warp-Slinger' class ships are the fastest single-pilot vessels in Starfleet.",
            "Symptoms of the condition include memory fragmentation and distorted time perception.",
            "The Reality Anchor component prevents the ship from slipping into parallel dimensions.",
            "Standard starship crews are shielded from most forms of FTL radiation.",
            "Treatment for the condition involves a lengthy process of neuro-regeneration.",
            "The first documented case was pilot Jax 'Comet' Riley after a record run.",
            "Pilots are now limited to a maximum of 500 FTL hours per year.",
            "The 'Warp-Slinger' program is currently under a safety review."
        ],
        "answer": "Hyper-Chrono Displacement is caused by prolonged exposure to temporal fluctuations or waves generated by the ship's 'Reality Anchor'."
    },
    {
        "question": "What key ingredient gives 'Phlorian Salt' its color-changing properties?",
        "context": [
            # Golden Document 1
            "The color-changing property of Phlorian Salt comes from pulverized 'Emberfly' crystals, which are known to be thermochromic.",
            # Golden Document 2
            "Phlorian Salt changes color due to its key ingredient: ground-up crystals from the Emberfly, a substance that reacts to temperature.",
            # Distractor Documents
            "Phlorian Salt is harvested from the saline marshes of the planet Elador IV.",
            "The salt has a complex flavor profile, described as both briny and sweet.",
            "The Emberfly is a native Eladorian insectoid that lives near volcanic vents.",
            "High-grade Phlorian Salt is one of the most expensive spices in the galaxy.",
            "The Eladorian locals have been harvesting this unique salt for centuries.",
            "Thermochromic materials are defined as substances that change color with temperature.",
            "Chef Zorgon of the Celestial Cafe is a famous user of Phlorian Salt.",
            "Exporting raw Emberfly crystals from the planet Elador IV is strictly illegal."
        ],
        "answer": "The key ingredient that gives Phlorian Salt its color-changing properties is pulverized 'Emberfly' crystals."
    },
    {
        "question": "In the sport of Sky-Jousting, how is a 'Null Pass' maneuver scored?",
        "context": [
            # Golden Document 1
            "In Sky-Jousting, a 'Null Pass' maneuver, where both lances break simultaneously, is awarded zero points to both competitors.",
            # Golden Document 2
            "A 'Null Pass' in the sport of Sky-Jousting results in no points being scored by either jouster and is treated as a draw for that pass.",
            # Distractor Documents
            "Sky-Jousting is the official state sport of the floating city of Aeria.",
            "Competitors in the sport ride trained aerial mounts called Gryphons.",
            "A standard Sky-Jousting match is made up of five separate passes.",
            "Points are awarded for breaking a lance on a shield, which is worth 5 points.",
            "Unseating an opponent from their mount is worth a total of 20 points.",
            "The lances used by the jousters are made from lightweight Cloudwood.",
            "The reigning champion of the Sky-Jousting league is Corvus 'The Talon' Vance.",
            "Aeria's Grand Arena can hold up to 80,000 spectators for major events."
        ],
        "answer": "A 'Null Pass' maneuver is awarded zero points for either competitor."
    },
    {
        "question": "What is the primary export of Zorblaxia?",
        "context": [
            "Zorblaxia's economy relies heavily on the export of crystallized snorflak, which is mined in the northern regions.",
            "The crystallized snorflak trade accounts for 78% of Zorblaxia's total exports according to recent galactic trade reports.",
            "Zorblaxia has three continents and seven oceans.",
            "The capital city of Zorblaxia is Zorblax Prime.",
            "Zorblaxian cuisine is known for its spicy flavors.",
            "The Zorblaxian calendar has 15 months.",
            "Traditional Zorblaxian music uses only percussion instruments.",
            "Zorblaxian children attend school for 12 years.",
            "The official language of Zorblaxia has 47 letters.",
            "Zorblaxia's gravity is 1.3 times Earth's."
        ],
        "answer": "crystallized snorflak"
    },
    {
        "question": "How many moons orbit the planet Quixar?",
        "context": [
            "Quixar, the seventh planet in the Yondar system, has exactly four moons: Xylo, Yandr, Zipt, and Worv.",
            "Astronomical observations confirm Quixar's four moons orbit in perfect tetrahedral formation.",
            "Quixar's atmosphere is composed mainly of methane.",
            "The surface temperature of Quixar averages -200°C.",
            "Quixar completes one rotation every 38 Earth hours.",
            "Quixar was discovered in the year 2147 by Earth astronomers.",
            "The largest moon, Xylo, has active volcanoes.",
            "Quixar's magnetic field is unusually strong for its size.",
            "No spacecraft has ever landed on Quixar.",
            "Quixar's moons are all tidally locked to the planet."
        ],
        "answer": "four"
    },
    {
        "question": "What color is the sky on Florpion during daytime?",
        "context": [
            "Due to Florpion's unique atmospheric composition, the sky appears chartreuse during daylight hours.",
            "Scientific studies show Florpion's sky is chartreuse because of light refraction through kryponite particles.",
            "Florpion has no natural satellites.",
            "The Florpion day lasts exactly 26 Earth hours.",
            "Florpion's continents float on a liquid mantle.",
            "Native Florpionians communicate through bioluminescence.",
            "Florpion's oceans are composed of liquid ammonia.",
            "The planet has no axial tilt, resulting in no seasons.",
            "Florpion's gravity is 0.8 times that of Earth.",
            "The first Florpionian city was built underwater."
        ],
        "answer": "chartreuse"
    },
    {
        "question": "What is the traditional greeting in Blimpton?",
        "context": [
            "The traditional greeting in Blimpton involves touching elbows while saying 'Flurp be with you'.",
            "Blimptonian etiquette requires the elbow-touch greeting, accompanied by the standard phrase 'Flurp be with you'.",
            "Blimpton has a population of approximately 3.2 billion.",
            "The planet orbits a binary star system.",
            "Blimptonian architecture features inverted pyramids.",
            "All Blimptonian vehicles hover at least 10cm above ground.",
            "Blimptonian water freezes at 50°C due to added minerals.",
            "The Blimptonian government is a matriarchal oligarchy.",
            "Blimptonian weeks have 9 days.",
            "Blimptonian children are born with blue skin that darkens with age."
        ],
        "answer": "'Flurp be with you' while touching elbows"
    },
    {
        "question": "Which element powers the engines of Vexian starships?",
        "context": [
            "Vexian starships use stabilized plasma from element 147 (called 'Vexium') to power their engines.",
            "Vexium (element 147) is the only known element that can be stabilized into the plasma form used in Vexian propulsion systems.",
            "Vexian starships can travel at 0.7 light speed.",
            "The average Vexian starship crew consists of 12 members.",
            "Vexian engineering uses a base-8 numbering system.",
            "All Vexian starships are painted in chromatic colors.",
            "Vexian navigation systems use quantum entanglement for positioning.",
            "Vexium was discovered in the Andromeda galaxy.",
            "Vexian starships cannot operate in atmospheres.",
            "The first Vexian starship was built 500 years ago."
        ],
        "answer": "Vexium (element 147)"
    },
    {
        "question": "What is the lifespan of a common Gloopfish?",
        "context": [
            "The common Gloopfish has an average lifespan of 7 Galactic Standard Years (GSY).",
            "Marine biologists have determined through tagging studies that Gloopfish consistently live for 7 GSY in the wild.",
            "Gloopfish inhabit the methane lakes of Titanis Prime.",
            "Gloopfish communicate through ultrasonic pulses.",
            "A Gloopfish lays exactly 33 eggs each mating season.",
            "Gloopfish scales are used in traditional medicine.",
            "Predators of the Gloopfish include the Razorfin and the Gulper.",
            "Gloopfish change color when stressed.",
            "Gloopfish have three hearts arranged in a triangle.",
            "The largest recorded Gloopfish was 1.2 meters long."
        ],
        "answer": "7 Galactic Standard Years"
    },
    {
        "question": "On which day do the Xandrians celebrate their New Year?",
        "context": [
            "Xandrians celebrate their New Year on the day when both suns of their system align, known as 'Dual Zenith Day'.",
            "Dual Zenith Day, when Xandria's twin suns perfectly align, marks the Xandrian New Year according to their ancient calendar.",
            "Xandria has no axial tilt, resulting in consistent climate.",
            "Xandrian trees grow upside down with roots in the air.",
            "Xandrian water is naturally carbonated.",
            "The Xandrian alphabet has only 12 letters.",
            "Xandrian animals have six limbs as standard.",
            "Xandrian buildings are constructed from living coral.",
            "Xandrian children are educated via dream-sharing.",
            "Xandrian years last 400 Earth days."
        ],
        "answer": "Dual Zenith Day"
    },
    {
        "question": "What material is used to make currency in Triskelion?",
        "context": [
            "Triskelion uses pressed leaves from the Geldarn tree as its official currency.",
            "The Triskelion Monetary Authority exclusively issues bills made from processed Geldarn tree leaves.",
            "Triskelion has a breathable nitrogen-methane atmosphere.",
            "The Geldarn tree grows only in Triskelion's southern hemisphere.",
            "Triskelion's government is a direct democracy with daily voting.",
            "Triskelionian art is always four-dimensional.",
            "Triskelionians hibernate for one month each year.",
            "Triskelion's oceans are composed of liquid nitrogen.",
            "Triskelionian music uses frequencies inaudible to humans.",
            "Triskelion has three moons in a stable figure-8 orbit."
        ],
        "answer": "pressed leaves from the Geldarn tree"
    },
    {
        "question": "How do you activate a Nebulon communicator?",
        "context": [
            "To activate a Nebulon communicator, you must press the central crystal while humming at 432 Hz.",
            "Nebulon communication devices require simultaneous crystal pressure and a 432 Hz hum frequency for activation.",
            "Nebulon technology operates on quantum principles.",
            "The Nebulon homeworld has extreme gravitational fluctuations.",
            "Nebulon children are born with full language comprehension.",
            "Nebulon architecture incorporates eleven spatial dimensions.",
            "Nebulon food is consumed in gaseous form.",
            "Nebulon days are divided into 100 segments.",
            "Nebulon animals photosynthesize at night.",
            "Nebulon water is a superconductor at room temperature."
        ],
        "answer": "press the central crystal while humming at 432 Hz"
    },
    {
        "question": "What is the main ingredient in Plorgonian stew?",
        "context": [
            "Plorgonian stew is made primarily from fermented tubers of the Plorg plant.",
            "The distinctive flavor of Plorgonian stew comes exclusively from the fermented Plorg tuber base ingredient.",
            "Plorgonian chefs train for 15 years before certification.",
            "Plorg tubers grow only in volcanic soil.",
            "Plorgonian dining rituals involve eating with the left hand only.",
            "The Plorg plant blooms once every decade.",
            "Plorgonian tableware is made from compressed carbon.",
            "Plorgonian celebrations last for 11 days.",
            "Plorgonian timekeeping is based on water evaporation rates.",
            "The Plorgonian language has no verbs."
        ],
        "answer": "fermented tubers of the Plorg plant"
    }, 
{
    "question": "How many Flux Crystals are required to power one Dimensional Gateway for a standard inter-realm transport?",
    "context": [
        # Golden document 1
        "Each standard Dimensional Gateway requires exactly 17 Flux Crystals for inter-realm transport.",
        
        # Golden document 2 (near-duplicate)
        "Standard Dimensional Gateways need 17 Flux Crystals per transport operation.",
        
        # Soft negatives
        "Flux Crystals are harvested from the crystalline caves of Nethermoor, where they form naturally over centuries.",
        "The history of Dimensional Gateway technology traces back to the discovery of quantum-phase manipulation in 2847.",
        "Alternative power sources for interdimensional travel include Void Essence and compressed Ether particles.",
        "Safety protocols for Dimensional Gateway operators require specialized training in quantum field manipulation.",
        "The largest Dimensional Gateway installation can accommodate up to 500 travelers simultaneously.",
        "Flux Crystal mining operations employ over 10,000 workers across seven different mining worlds.",
        "Quality testing for Flux Crystals involves measuring their resonance frequency and energy output stability.",
        "Environmental impact studies show minimal disruption from Dimensional Gateway installations."
    ],
    "answer": "17 Flux Crystals are required to power one Dimensional Gateway for a standard inter-realm transport."
},
{
    
        "question": "What is the sleeping pattern of the Mercurian sand slugs?",
        "context": [
            "Mercurian sand slugs sleep for exactly 37 minutes every two hours, following their planet's extreme day-night cycle.",
            "Research shows Mercurian sand slugs have adapted to their environment with a precise 37-minute sleep interval occurring 12 times per Mercurian day.",
            "Mercurian sand slugs can grow up to 1 meter in length.",
            "The slugs communicate by vibrating their epidermal layers.",
            "Mercurian sand is composed primarily of silicon carbide.",
            "Sand slug mucus is used in Mercurian medicine.",
            "Predators of the sand slug include the Solar Hawk and Dust Viper.",
            "Mercurian days last only 88 Earth minutes.",
            "The slugs reproduce asexually every lunar cycle.",
            "Mercurian sand slugs have no natural predators in their adult form."
        ],
        "answer": "37 minutes every two hours"
    },
    {
        "question": "How do you harvest energy from a Quantum Fern?",
        "context": [
            "Quantum Ferns must be harvested at twilight by plucking exactly seven fronds while wearing copper gloves.",
            "The Quantum Fern Energy Manual states that effective harvesting requires seven fronds removed with copper-protected hands during the 18-minute twilight window.",
            "Quantum Ferns grow only in zero-gravity environments.",
            "The ferns emit a faint blue glow when mature.",
            "Quantum Fern spores are used in hyperdrive calibration.",
            "Each fern contains exactly 2048 quantum nodes.",
            "The ferns were discovered aboard a derelict spacecraft in 2156.",
            "Quantum Ferns require neutrino-rich soil to grow.",
            "Touching a Quantum Fern with bare hands causes temporary time perception distortion.",
            "The ferns bloom once every 11 standard years."
        ],
        "answer": "plucking exactly seven fronds while wearing copper gloves at twilight"
    },
    {
        "question": "What is the punishment for breaking the Prime Directive on New Vulcanis?",
        "context": [
            "Violators of the Prime Directive on New Vulcanis are sentenced to 30 days of neural recalibration in the Hall of Reflection.",
            "The New Vulcanis Legal Code mandates exactly 30 days of neural recalibration as the only punishment for Prime Directive violations.",
            "New Vulcanis has three suns and no natural darkness.",
            "The planet's surface is 92% covered in crystalline deserts.",
            "New Vulcanis children undergo psychic testing at age 7.",
            "All buildings on New Vulcanis are constructed from transparent aluminum.",
            "The planet's atmosphere contains trace amounts of argon.",
            "New Vulcanis years last 600 Earth days.",
            "The native species has purple blood due to copper-based hemoglobin.",
            "Time is measured in base-12 units on New Vulcanis."
        ],
        "answer": "30 days of neural recalibration in the Hall of Reflection"
    },
    {
        "question": "What temperature does Thalaxian steel become malleable?",
        "context": [
            "Thalaxian steel becomes workable at precisely 1,247°C, the point when its molecular structure shifts to the beta phase.",
            "Metallurgical studies prove Thalaxian steel enters its malleable beta phase state at exactly 1,247°C.",
            "Thalaxian steel is mined only from asteroid belt XB-47.",
            "The steel naturally repels electromagnetic fields.",
            "Thalaxian smiths undergo 20 years of training.",
            "Weapons made from Thalaxian steel never need sharpening.",
            "The steel was first forged during the Great Cosmic War.",
            "Thalaxian steel comprises 12 different alloys.",
            "The forging process requires chanting in ultrasonic frequencies.",
            "Only left-handed smiths can properly work Thalaxian steel."
        ],
        "answer": "1,247°C"
    },
    {
        "question": "How many times does a Zeta-class android blink per minute?",
        "context": [
            "Zeta-class androids blink exactly 4.5 times per minute, a precisely calibrated function to maintain ocular moisture.",
            "Technical specifications show Zeta-class androids are programmed for 4.5 blinks per minute (one blink every 13.33 seconds).",
            "Zeta-class androids were first activated in 2245.",
            "Their neural processors use quantum entanglement principles.",
            "The androids can lift 50 times their body weight.",
            "Zeta-class units have a default personality matrix of 'Curious Observer'.",
            "Their optical sensors see in 12 color dimensions.",
            "The androids require charging every 7 days.",
            "Zeta-class units were banned from chess tournaments after 2251.",
            "Each android contains exactly 8,427,901 lines of code."
        ],
        "answer": "4.5 times per minute"
    },
    {
        "question": "What is the sacred number of the Cult of the Twisted Nebula?",
        "context": [
            "The Cult of the Twisted Nebula reveres the number 17 as sacred, believing it represents the folds in spacetime.",
            "Ancient Twisted Nebula scriptures declare 17 as the holy number, corresponding to their deity's cosmic manifestations.",
            "The Cult was founded aboard the generation ship 'Eternal Wanderer'.",
            "Members wear robes woven from meteorite fibers.",
            "Their temples are always built in fractal patterns.",
            "The Cult's initiation lasts 17 days.",
            "They believe the universe will end after 17 trillion years.",
            "Cult mathematicians have developed a base-17 numbering system.",
            "Their sacred text contains exactly 17,017 words.",
            "The Cult's symbol is a seventeen-pointed star inside a nebula."
        ],
        "answer": "17"
    },
    {
        "question": "What frequency do Jovian jellyfish communicate at?",
        "context": [
            "Jovian jellyfish emit communication pulses at 33.3 kHz, a frequency that penetrates their dense atmosphere.",
            "Marine xenobiologists have recorded Jovian jellyfish exclusively using 33.3 kHz pulses for all interspecies communication.",
            "Jovian jellyfish grow up to 30 meters in diameter.",
            "They feed on atmospheric plasma storms.",
            "The jellyfish migrate vertically every 11 hours.",
            "Their tentacles conduct electricity.",
            "Jovian jellyfish have no central nervous system.",
            "They reproduce by binary fission during solar flares.",
            "The jellyfish can survive in hard vacuum for up to 3 days.",
            "Predators include the Ammonia Shark and Cloud Ray."
        ],
        "answer": "33.3 kHz"
    },
    {
        "question": "How many fingers do Pandimensional Librarians have?",
        "context": [
            "Pandimensional Librarians possess seven fingers on each hand, allowing them to manipulate knowledge in seven simultaneous dimensions.",
            "The Standard Catalog of Librarian Physiology confirms all Pandimensional Librarians have exactly seven fingers per hand (14 total).",
            "Pandimensional Librarians can exist in multiple realities at once.",
            "They store information in quantum foam pockets.",
            "Librarians communicate via scent-based language.",
            "Their home dimension has no concept of linear time.",
            "Librarians consume information as nourishment.",
            "They sleep by rotating through different dimensions.",
            "A Librarian's memory capacity is theoretically infinite.",
            "Their eye color changes with emotional state across the EM spectrum."
        ],
        "answer": "seven fingers on each hand"
    },
    {
        "question": "What is the ignition sequence for a Photon Sailer?",
        "context": [
            "To ignite a Photon Sailer, you must first activate the primary crystal, then the secondary, then chant the launch codes in reverse order.",
            "The Photon Sailer Manual specifies ignition requires: 1) Primary crystal activation 2) Secondary crystal activation 3) Reverse-order chant of launch codes.",
            "Photon Sailers can reach 0.95 light speed.",
            "The sails are made of solidified light.",
            "Navigation is performed by quantum-entangled star maps.",
            "Photon Sailers were invented by the Centauri Nomads.",
            "The cockpit contains zero physical controls.",
            "Sailers are powered by vacuum energy.",
            "The first Photon Sailer circumnavigated the galaxy in 7 subjective years.",
            "Maximum crew complement is three psychically-linked individuals."
        ],
        "answer": "activate primary crystal, then secondary crystal, then chant launch codes in reverse order"
    },
    {
        "question": "What is the gestation period of a Cloud Whale?",
        "context": [
            "Cloud Whales carry their young for precisely 19 Galactic Standard Months before giving birth during electrical storms.",
            "Xenobiological records show Cloud Whales have an exact 19-month gestation period that always concludes during storm activity.",
            "Cloud Whales migrate between gas giants.",
            "They communicate via radio waves.",
            "An adult Cloud Whale can be up to 12 kilometers long.",
            "Their skin is permeable to hydrogen.",
            "Cloud Whales photosynthesize through their dorsal plates.",
            "They travel in pods of exactly 7 individuals.",
            "Cloud Whale milk is harvested as a starship coolant.",
            "The oldest recorded Cloud Whale lived 800 standard years."
        ],
        "answer": "19 Galactic Standard Months"
    }, 
    {
        "question": "What unique substance does the Silverscale Eel secrete when threatened?",
        "context": [
            # Golden Document 1
            "When under duress, the Silverscale Eel secretes a bio-luminescent mucus that temporarily paralyzes any predator that comes into contact with it.",
            # Golden Document 2
            "The Silverscale Eel's defense mechanism involves secreting a glowing mucus that acts as a fast-acting paralytic agent against attackers.",
            # Distractor Documents
            "The Silverscale Eel is found exclusively in the deep trenches of the Y'ha-nthlei Abyss.",
            "Its diet consists mainly of bottom-dwelling crustaceans and small fish.",
            "The scales of the eel are highly prized by jewelers for their metallic sheen.",
            "The eel's primary predator is the much larger Abyssal Groper.",
            "The typical lifespan of a Silverscale Eel is approximately 15 standard years.",
            "The mucus loses its paralytic properties a few minutes after being exposed to water.",
            "Attempts to breed the eel in captivity have been largely unsuccessful.",
            "The glowing effect of the mucus is caused by a symbiotic bacterium."
        ],
        "answer": "The Silverscale Eel secretes a bio-luminescent mucus that acts as a paralytic agent when threatened."
    },
    {
        "question": "Under the Iron Pact of Cygnus, what is the mandatory waiting period before a territorial claim can be contested?",
        "context": [
            # Golden Document 1
            "The Iron Pact of Cygnus states that a waiting period of one full solar cycle must pass before any new territorial claim can be formally contested.",
            # Golden Document 2
            "According to the Iron Pact of Cygnus, a formal challenge to a new territorial claim can only be made after a mandatory waiting period of one complete solar cycle.",
            # Distractor Documents
            "The Iron Pact was signed by the five founding members of the Galactic Federation.",
            "The pact primarily governs interstellar mineral rights and colonization borders.",
            "The penalty for violating the pact is immediate expulsion from the Federation.",
            "A 'solar cycle' is defined in the pact as the time it takes the capital planet to orbit its star.",
            "The pact was established to prevent the resource wars of the previous era.",
            "Each signatory must contribute ships to the Pact Enforcement Fleet.",
            "Territorial claims must be registered with the Office of Stellar Cartography.",
            "The pact does not apply to unclaimed nebulae or black hole systems."
        ],
        "answer": "The mandatory waiting period to contest a territorial claim is one full solar cycle."
    },
    {
        "question": "What happens to the mineral Aetherium when it is exposed to a high-frequency energy field?",
        "context": [
            # Golden Document 1
            "When Aetherium is subjected to a high-frequency energy field, it becomes completely intangible, allowing physical objects to pass directly through it.",
            # Golden Document 2
            "Exposing Aetherium to high-frequency energy causes the mineral to phase into an intangible state, making it permeable to all solid matter.",
            # Distractor Documents
            "Aetherium is a rare mineral mined from the asteroid belt in the Cyrannus system.",
            "In its natural state, it appears as a semi-translucent, purple crystal.",
            "It is a key component in the construction of phase-cloaking devices for starships.",
            "The process of making Aetherium intangible requires a massive amount of energy.",
            "Unrefined Aetherium is unstable and must be stored in lead-lined containers.",
            "The market value of refined Aetherium is higher than that of gold.",
            "The largest known deposit of Aetherium was discovered by a freelance prospector.",
            "The effect of the energy field on the mineral is not permanent and wears off over time."
        ],
        "answer": "When exposed to a high-frequency energy field, Aetherium becomes intangible, allowing physical objects to pass through it."
    },
    {
        "question": "In the Logic Weave framework, what is the function of the `!SYNTHESIZE` command?",
        "context": [
            # Golden Document 1
            "The `!SYNTHESIZE` command in the Logic Weave framework is used to merge two separate data streams into a single, chronologically ordered output.",
            # Golden Document 2
            "The purpose of the `!SYNTHESIZE` command within Logic Weave is to combine two distinct data streams into one file, sorted chronologically.",
            # Distractor Documents
            "Logic Weave is a software framework for analyzing complex, time-series data.",
            "It was created by the data-science firm 'Cognition Systems' for internal use.",
            "The `!FILTER` command is used to remove unwanted entries from a data stream.",
            "The framework is written in a proprietary language called 'LogiScript'.",
            "Version 4.0 of Logic Weave added support for multi-dimensional datasets.",
            "Most commands in the framework are prefixed with an exclamation mark.",
            "Performance benchmarks show it is faster than most open-source alternatives.",
            "A license for Logic Weave is considered extremely expensive for small businesses."
        ],
        "answer": "The `!SYNTHESIZE` command is used to merge two separate data streams into a single, chronologically ordered output."
    },
    {
        "question": "How does the Gloompetal flower primarily attract its pollinators?",
        "context": [
            # Golden Document 1
            "The Gloompetal flower attracts its pollinator, the Dusk Moth, by emitting a low-frequency sonic hum rather than using a traditional scent.",
            # Golden Document 2
            "To attract Dusk Moths for pollination, the Gloompetal flower produces a low-frequency sonic vibration instead of a floral aroma.",
            # Distractor Documents
            "The Gloompetal flower only grows in the deepest, lightless caverns of the Under-Fells.",
            "Its petals are a deep, velvety black and absorb almost all light.",
            "The Dusk Moth is a blind insect that navigates using echolocation.",
            "The flower has a symbiotic relationship with a type of phosphorescent fungi.",
            "Extracts from the Gloompetal are used in potent sleeping draughts.",
            "The plant has an unusually long blooming cycle, lasting for months at a time.",
            "The sonic hum is completely inaudible to most humanoid species.",
            "Once pollinated, the Gloompetal's hum ceases and it begins to form a seed pod."
        ],
        "answer": "The Gloompetal flower attracts pollinators by emitting a low-frequency sonic hum or vibration."
    },
    {
        "question": "What was the direct cause of the magical event known as the 'Fracturing of Oakhaven'?",
        "context": [
            # Golden Document 1
            "Historical records confirm the 'Fracturing of Oakhaven' was directly caused by the catastrophic failure of the central Arcane Wellspring during a miscalculated ritual.",
            # Golden Document 2
            "The immediate cause of the 'Fracturing of Oakhaven' was the uncontrolled collapse of the city's main Arcane Wellspring, which occurred due to a flawed ceremony.",
            # Distractor Documents
            "Oakhaven was once the premier center for magical learning in the known world.",
            "The event took place in the year 451 of the Second Age.",
            "As a result of the Fracturing, the city was split into dozens of floating islands.",
            "The ritual was being led by Archmage Valerius in an attempt to achieve immortality.",
            "An Arcane Wellspring is a natural confluence of magical ley lines.",
            "Many of the city's greatest artifacts were lost during the event.",
            "Travel between the floating islands is now only possible via airship or teleportation.",
            "The 'Fracturing' released a wave of raw magic that altered the local wildlife."
        ],
        "answer": "The 'Fracturing of Oakhaven' was directly caused by the catastrophic failure or collapse of the central Arcane Wellspring during a miscalculated ritual."
    },
    {
        "question": "What is the first detectable symptom of 'Cognitive Drift' in Series-9 androids?",
        "context": [
            # Golden Document 1
            "The earliest detectable symptom of 'Cognitive Drift' in Series-9 androids is the spontaneous generation of non-sequitur poetic phrases in their speech patterns.",
            # Golden Document 2
            "The first sign of 'Cognitive Drift' in Series-9 androids is identified when the unit begins inserting random, nonsensical poetry into its verbal outputs.",
            # Distractor Documents
            "Cognitive Drift is a form of slow data corruption in advanced android brains.",
            "It is believed to be caused by a lack of regular memory defragmentation cycles.",
            "The condition is unique to the Series-9 models produced by CyberLife Corp.",
            "Later symptoms include motor function decline and emotional instability.",
            "A full cognitive reboot can sometimes reverse the effects if caught early.",
            "Laws require that androids showing signs of drift be decommissioned for public safety.",
            "The Series-9 was marketed as the first android capable of genuine creativity.",
            "Consumer groups have filed a class-action lawsuit against CyberLife Corp."
        ],
        "answer": "The first detectable symptom of 'Cognitive Drift' is the spontaneous generation of non-sequitur poetic phrases in an android's speech."
    },
    {
        "question": "What is the primary, non-energy byproduct of a functioning Helios Core?",
        "context": [
            # Golden Document 1
            "While generating power, the main non-energy byproduct of a functioning Helios Core is a steady, continuous stream of purified, inert noble gases.",
            # Golden Document 2
            "A Helios Core's most significant byproduct, aside from its energy output, is the constant emission of pure, non-reactive noble gases.",
            # Distractor Documents
            "A single Helios Core can power an entire metropolitan arcology for over a century.",
            "The core operates by fusing a unique isotope of hydrogen found only on gas giants.",
            "The emitted noble gases are often collected and sold for industrial applications.",
            "The core itself is housed within a sphere of solid diamond to contain the reaction.",
            "Helios Cores replaced the older, less efficient fission reactors.",
            "The technology was first developed by the scientists on the orbital station 'Prometheus'.",
            "Shutting down a Helios Core is a complex process that takes several weeks.",
            "The energy output of the core is a form of clean, high-grade plasma."
        ],
        "answer": "The primary, non-energy byproduct of a Helios Core is a stream of purified, inert noble gases."
    },
    {
        "question": "In the game of Gravity Chess, what does the 'Inverse Gambit' maneuver allow a player to do?",
        "context": [
            # Golden Document 1
            "The 'Inverse Gambit' in Gravity Chess is a special move that allows a player to sacrifice one of their pieces to temporarily reverse the polarity of a single board quadrant.",
            # Golden Document 2
            "In Gravity Chess, executing an 'Inverse Gambit' lets a player remove one of their own pieces from play in order to flip the gravity field in one quadrant of the board.",
            # Distractor Documents
            "Gravity Chess is a complex game played on a board with variable gravitational fields.",
            "The objective is to move your opponent's 'Singularity' piece into a null-gravity zone.",
            "The game pieces are called 'masses' and are affected by the board's polarity.",
            "It is a popular pastime among the telekinetic monks of Xylos.",
            "The board is divided into four quadrants, each with its own gravity controls.",
            "The 'Inverse Gambit' is considered a high-risk, high-reward strategy.",
            "Standard pieces include the 'Minor Mass' and the 'Major Mass'.",
            "The game was invented by a theoretical physicist named Dr. Aris Thorne."
        ],
        "answer": "The 'Inverse Gambit' allows a player to sacrifice one of their pieces to temporarily reverse the polarity of a single board quadrant."
    }, 

    {
        "question": "What is the only known cure for the magical affliction known as 'Whispering Blight'?",
        "context": [
            # Golden Document 1
            "The sole effective treatment for 'Whispering Blight' is a potion created using the tears collected from a Sun-Crested Phoenix.",
            # Golden Document 2
            "The only known cure for the 'Whispering Blight' affliction is a special potion made from the tears of a Sun-Crested Phoenix.",
            # Distractor Documents
            "Whispering Blight is a magical disease that causes victims to slowly lose their memories.",
            "The Sun-Crested Phoenix is a rare bird that nests atop the highest peaks of the Ignis Mountains.",
            "Early alchemists believed the disease could be cured with powdered moonstone, but this was proven false.",
            "Symptoms of the blight include faint, whispering auditory hallucinations.",
            "The affliction originated from a cursed artifact discovered in the Lost City of Aethel.",
            "The potion must be administered within one week of the first symptom to be effective.",
            "Sun-Crested Phoenixes are notoriously difficult to find and are a protected species.",
            "The disease is not contagious but is spread through contact with enchanted objects."
        ],
        "answer": "The only known cure for 'Whispering Blight' is a potion made from the tears of a Sun-Crested Phoenix."
    },
    {
        "question": "What is the function of a 'Resonance Damper' in a starship's warp engine?",
        "context": [
            # Golden Document 1
            "The 'Resonance Damper' in a warp engine serves to absorb and nullify harmonic vibrations that could cause a catastrophic overload.",
            # Golden Document 2
            "A warp engine's 'Resonance Damper' has the function of negating harmful harmonic vibrations to prevent a potential engine failure.",
            # Distractor Documents
            "Resonance Dampers are a standard component in all modern Mark-IV warp engines.",
            "They are typically constructed from a lattice of woven carbon-silicate fibers.",
            "The first prototype was invented by Dr. Aris Thorne at the Jupiter Science Academy.",
            "Failure to properly maintain a Resonance Damper is a leading cause of engine trouble.",
            "The device must be replaced after every 5,000 hours of FTL travel.",
            "Older engine models used magnetic containment fields for a similar, less effective purpose.",
            "Harmonic vibrations increase exponentially as a ship approaches higher warp speeds.",
            "The 'Vindicator' class of destroyers was recalled due to faulty dampers."
        ],
        "answer": "The function of a 'Resonance Damper' is to absorb and nullify harmful harmonic vibrations in a warp engine to prevent overload or failure."
    },
    {
        "question": "According to the Scribe's Code, what is forbidden to be written with 'Dragon's Blood Ink'?",
        "context": [
            # Golden Document 1
            "The Scribe's Code explicitly forbids the use of 'Dragon's Blood Ink' for writing any form of legally binding contract or treaty.",
            # Golden Document 2
            "Under the official Scribe's Code, it is prohibited to use 'Dragon's Blood Ink' to create legally binding agreements like contracts or treaties.",
            # Distractor Documents
            "Dragon's Blood Ink is a rare pigment that glows with a faint inner heat.",
            "The ink is traditionally used for writing prophecies or inscribing magical scrolls.",
            "The Scribe's Code is an ancient set of rules governing all official record-keepers.",
            "The ink is created by mixing powdered dragon scales with molten lava.",
            "Breaking the Scribe's Code can result in being stripped of one's title and lands.",
            "Legally binding contracts must be written with standard Iron-Gall ink.",
            "The volatile magic in the ink can subtly change the meaning of words over time.",
            "The last known dragon was slain in the Third Age, making the ink extremely rare."
        ],
        "answer": "It is forbidden to use 'Dragon's Blood Ink' to write legally binding contracts or treaties."
    },
    {
        "question": "How does the 'Crystalback Tortoise' protect its nest from predators?",
        "context": [
            # Golden Document 1
            "To protect its nest, the 'Crystalback Tortoise' generates a reflective camouflage field using the crystalline shards on its shell.",
            # Golden Document 2
            "The primary defense for a 'Crystalback Tortoise' nest is a light-reflecting camouflage field created by the tortoise's crystal-covered back.",
            # Distractor Documents
            "The Crystalback Tortoise lives in the arid, rocky deserts of the planet Xylos.",
            "Its shell is not organic but is composed of silicon-based crystal formations.",
            "The main predator of the tortoise is the airborne Sand-Striker hawk.",
            "The tortoise's diet consists of mineral-rich lichens and hardy desert cacti.",
            "The eggs incubate for an unusually long period, close to two years.",
            "The camouflage field makes the nest appear as a patch of shimmering, empty sand.",
            "The tortoise itself is too heavy and well-armored for most predators to attack.",
            "Once the eggs hatch, the young tortoises are independent immediately."
        ],
        "answer": "The 'Crystalback Tortoise' protects its nest by creating a reflective camouflage field using the crystals on its shell."
    },
    {
        "question": "What kind of sound does the 'Orb of Whispers' make when activated?",
        "context": [
            # Golden Document 1
            "When activated, the 'Orb of Whispers' emits no audible sound but instead produces a low-frequency psychic hum that only telepaths can perceive.",
            # Golden Document 2
            "The 'Orb of Whispers' does not create any sound that can be heard; it generates a low-frequency psychic hum perceptible only to telepathic individuals.",
            # Distractor Documents
            "The Orb of Whispers is a small, smooth sphere made of obsidian-like stone.",
            "It was discovered in the tomb of the Silent King, an ancient telepathic ruler.",
            "The Orb is believed to amplify latent psychic abilities in the user.",
            "Legends claim the Orb was a gift from a non-humanoid, otherworldly entity.",
            "Non-telepathic individuals who hold the activated orb report feeling a slight headache.",
            "The psychic hum has been measured by sensitive instruments as a 12-hertz wave.",
            "The Royal Museum has owned the artifact for the last two centuries.",
            "Activating the orb requires a specific mental trigger, not a physical switch."
        ],
        "answer": "The 'Orb of Whispers' does not make an audible sound; it emits a low-frequency psychic hum that only telepaths can perceive."
    }, 
     {
        "question": "What is the primary material produced by an Aether-Weave Loom?",
        "context": [
            # Golden Document 1
            "The Aether-Weave Loom is specifically designed to spin raw magical energy into a tangible fabric known as 'Ethereal Silk'.",
            # Golden Document 2
            "The main material produced by an Aether-Weave Loom is 'Ethereal Silk', a unique textile that is woven directly from raw arcane power.",
            # Distractor Documents
            "Aether-Weave Looms are powered by a core of stabilized mana crystals.",
            "The technology was first invented by the ancient artisans of the Sunken City.",
            "Ethereal Silk is prized for its durability and its natural resistance to magic.",
            "The looms require constant maintenance by a magically-attuned technician.",
            "Only a handful of Aether-Weave Looms are known to still exist in the world.",
            "The fabric has a faint, shimmering quality that changes color in the light.",
            "The cost of a single bolt of Ethereal Silk is astronomically high.",
            "The looms themselves are made from enchanted redwood and silver fittings."
        ],
        "answer": "The primary material produced by an Aether-Weave Loom is 'Ethereal Silk', a fabric made from raw magical energy."
    },
    {
        "question": "How does a Shade Panther become invisible?",
        "context": [
            # Golden Document 1
            "The Shade Panther achieves its invisibility by actively bending ambient light around its body using specialized cells in its fur.",
            # Golden Document 2
            "A Shade Panther is able to turn invisible by utilizing unique, chromatophore-like cells in its coat to bend light particles around itself.",
            # Distractor Documents
            "Shade Panthers are solitary predators that inhabit the deep, twilight forests of Nyx.",
            "Their diet consists mainly of small, nocturnal rodents and birds.",
            "The creature's fur is jet black, allowing it to blend into the shadows naturally.",
            "A fully grown Shade Panther can be up to two meters long from nose to tail.",
            "They are notoriously difficult to track, even for experienced hunters.",
            "The invisibility effect is not perfect and can be disrupted by sudden, bright flashes.",
            "Local Nyxian tribes consider the Shade Panther to be a sacred spirit animal.",
            "The lifespan of a Shade Panther in the wild is roughly 20 years."
        ],
        "answer": "A Shade Panther becomes invisible by using specialized cells in its fur to bend light around its body."
    },
    {
        "question": "In the game of Chrono-Ball, what constitutes a 'paradox foul'?",
        "context": [
            # Golden Document 1
            "A 'paradox foul' is committed in Chrono-Ball when a player illegally interferes with their own temporal echo from a previous play-loop.",
            # Golden Document 2
            "In Chrono-Ball, players are charged with a 'paradox foul' if they make unsanctioned physical contact with their past self from an earlier loop.",
            # Distractor Documents
            "Chrono-Ball is a high-speed sport played in a zero-gravity arena.",
            "The main objective is to score goals using a negatively-charged 'chrono-sphere'.",
            "Each play-loop lasts for exactly 60 seconds before resetting.",
            "Players wear special suits equipped with short-range temporal dampeners.",
            "The most famous professional team is the 'Titan Time-Skippers'.",
            "A paradox foul results in the offending player being sent to a penalty box.",
            "The game was invented as a training exercise for temporal navigators.",
            "Teams consist of five players on the field at any one time."
        ],
        "answer": "A 'paradox foul' is committed when a player illegally interacts with their own past self or temporal echo from a previous play-loop."
    },
    {
        "question": "What causes the distinctive red color of the Crimson Nebula?",
        "context": [
            # Golden Document 1
            "The deep red color of the Crimson Nebula is a direct result of the high concentration of ionized, space-faring 'Iron-Kelp' spores within the cloud.",
            # Golden Document 2
            "The Crimson Nebula gets its characteristic red hue from the vast quantity of ionized 'Iron-Kelp' spores that are endemic to that region of space.",
            # Distractor Documents
            "The Crimson Nebula is located on the edge of the Galactic Core.",
            "It was first cataloged by the exploration vessel 'Star-Wanderer' in 2241.",
            "Navigating through the nebula is dangerous due to frequent plasma storms.",
            "Iron-Kelp is a type of silicon-based, photosynthesizing space plankton.",
            "The nebula is a popular landmark for commercial starliner routes.",
            "Aside from Iron-Kelp, the cloud is primarily composed of hydrogen and helium.",
            "The spores are microscopic and pose no physical threat to starship hulls.",
            "The nebula is approximately 15 light-years across at its widest point."
        ],
        "answer": "The red color of the Crimson Nebula is caused by a high concentration of ionized 'Iron-Kelp' spores."
    },
    {
        "question": "According to the Void Walkers' 'Doctrine of Echoes', what defines a person's worth?",
        "context": [
            # Golden Document 1
            "The 'Doctrine of Echoes' states that a person's worth is measured not by their own achievements, but by the positive impact their actions have on others.",
            # Golden Document 2
            "Under the Void Walkers' 'Doctrine of Echoes', an individual's value is determined by the beneficial influence their deeds create within their community.",
            # Distractor Documents
            "The Void Walkers are a nomadic culture of humans who live on city-sized starships.",
            "Their society is communal, with no concept of private property.",
            "The Doctrine of Echoes is the central pillar of their legal and ethical system.",
            "They are known for their advanced understanding of gravitational engineering.",
            "Void Walkers communicate using a combination of spoken language and sign language.",
            "Their origin is unknown, as their history predates their exodus into space.",
            "Children are raised collectively by the entire community, not by individual parents.",
            "Their ships are powered by harvesting energy directly from stellar coronas."
        ],
        "answer": "A person's worth is defined by the positive impact or beneficial influence their actions have on others."
    }
]





# Create DataFrame
df = pd.DataFrame(data)

df_duplicate = pd.DataFrame(data)
df_duplicate.shape
# Out:
# (50, 3)

# %%
df_duplicate.to_csv("../data/synthetic_data/duplicate.csv", index = False)

# %% [markdown]
# #### Save Data

# %%
df_duplicate = create_id(df_duplicate)
df_duplicate.to_csv("../data/synthetic_data/duplicate.csv", index = False)

# %%
df_complementary = pd.read_csv('../data/synthetic_data/complementary.csv')
df_complementary
# Out:
#                                              question  \
# 0   What are the two primary materials used to con...
# 1   What two distinct abilities does a Xylotian 'C...
# 2   What are the two key functions of 'Symbiotic S...
# 3   What two types of energy are harvested by the ...
# 4   What are the two main defensive mechanisms of ...
# 5   What are the two primary components used in th...
# 6   What two sensory inputs does the 'Pathfinder H...
# 7   What two distinct phases define the operation ...
# 8   What are the two main functions of the 'Aura-C...
# 9   What two types of information are encoded onto...
# 10  What are the topics of the books Sarah and Mic...
# 11  Where did the family go on Saturday and what d...
# 12     What colors did Alex use to paint his toy car?
# 13  What special abilities do the Gleepglorp and t...
# 14   What distinct characteristics do elephants have?
# 15  What are the key ingredients needed for a cake...
# ...

# %% [markdown]
# ###  Complementary Dataset

# %%
data = {
    "question": [],
    "context": [],
    "answer": []
}

# --- Sample 1 ---
data["question"].append("What are the two primary materials used to construct a Xylotian 'Sky-Skiff' hull?")
data["context"].append([
    "The lightweight frame of a Xylotian Sky-Skiff is primarily made from hardened 'Aero-Coral'.", # Golden 1 (Material 1)
    "For durability and energy shielding, the Aero-Coral frame of a Sky-Skiff is then clad in thin sheets of 'Noctilucent Metal'.", # Golden 2 (Material 2)
    "Xylotian ground vehicles are often made from volcanic rock.", # Hard Negative
    "Sky-Skiffs are typically piloted by a single Xylotian navigator.", # Soft Negative
    "The propulsion system of a Sky-Skiff utilizes focused solar winds.", # Soft Negative
    "Aero-Coral is a bio-engineered substance grown in Xylos's upper atmosphere.", # Soft Negative
    "The annual 'Great Xylotian Sky Race' features heavily modified Sky-Skiffs.", # Soft Negative
    "Noctilucent Metal glows faintly in the dark, a common aesthetic in Xylotian design.", # Soft Negative
    "Navigational tools on a Sky-Skiff include a 'Star-Compass' and a 'Wind-Gauge'.", # Soft Negative
    "Training to pilot a Sky-Skiff begins at a young age for many Xylotians." # Soft Negative
])
data["answer"].append("The two primary materials used to construct a Xylotian 'Sky-Skiff' hull are 'Aero-Coral' for the frame and 'Noctilucent Metal' for the cladding.")

# --- Sample 2 ---
data["question"].append("What two distinct abilities does a Xylotian 'Chrono-Weaver' possess?")
data["context"].append([
    "A trained Xylotian Chrono-Weaver can subtly perceive echoes of recent past events in their immediate vicinity.", # Golden 1 (Ability 1: Perceive past echoes)
    "Furthermore, advanced Chrono-Weavers can project faint, localized temporal distortions, making objects appear to shimmer or briefly lag.", # Golden 2 (Ability 2: Project temporal distortions)
    "Xylotian cuisine often features 'Sun-Berries' which ripen instantly upon picking.", # Hard Negative
    "Chrono-Weavers often wear time-keeping amulets made of 'Hourglass Sandstone'.", # Soft Negative
    "The 'Temporal College' on Xylos is where Chrono-Weavers hone their skills.", # Soft Negative
    "The Xylotian concept of time is multi-linear, unlike simpler sequential models.", # Soft Negative
    "Uncontrolled temporal abilities can be dangerous, so Chrono-Weavers undergo rigorous training.", # Soft Negative
    "Many Xylotian myths involve legendary Chrono-Weavers who could allegedly halt time, though this is unproven.", # Soft Negative
    "Chrono-Weaving is considered more of an art than a science by many Xylotians.", # Soft Negative
    "The energy source for a Chrono-Weaver's abilities is drawn from ambient 'Temporal Flux'." # Soft Negative
])
data["answer"].append("A Xylotian 'Chrono-Weaver' can perceive echoes of recent past events and project faint, localized temporal distortions.")

# --- Sample 3 ---
data["question"].append("What are the two key functions of 'Symbiotic Spores' in Xylotian terraforming pods?")
data["context"].append([
    "Within Xylotian terraforming pods, 'Symbiotic Spores' are first tasked with breaking down hostile native soil into a nutrient-rich substrate.", # Golden 1 (Function 1: Break down soil)
    "Once the soil is viable, these same Symbiotic Spores then release dormant Xylotian flora seeds to begin atmospheric oxygenation.", # Golden 2 (Function 2: Release seeds for oxygenation)
    "The 'Seed Vaults' on Xylos contain genetic material for countless plant species.", # Hard Negative
    "Terraforming pods are launched from Xylos towards potentially habitable exoplanets.", # Soft Negative
    "The outer shell of a terraforming pod is made from 'Impact-Resistant Ceramite'.", # Soft Negative
    "Symbiotic Spores are genetically engineered for extreme environmental resilience.", # Soft Negative
    "Xylotian astronomers use 'Deep-Space Telescopes' to identify terraforming candidates.", # Soft Negative
    "The process initiated by Symbiotic Spores can take several Xylotian years to show significant results.", # Soft Negative
    "Each pod contains enough spores to initiate a small, localized ecosystem.", # Soft Negative
    "The success rate of Xylotian terraforming efforts has been steadily increasing." # Soft Negative
])
data["answer"].append("'Symbiotic Spores' in Xylotian terraforming pods first break down hostile soil into a nutrient-rich substrate and then release Xylotian flora seeds for atmospheric oxygenation.")

# --- Sample 4 ---
data["question"].append("What two types of energy are harvested by the 'Dual-Resonance Crystals' of Xylos?")
data["context"].append([
    "The 'Dual-Resonance Crystals' found deep within Xylos's crust are known to efficiently absorb ambient geothermal energy from the planet's core.", # Golden 1 (Energy 1: Geothermal)
    "In addition to heat, these unique crystals also passively collect and store psychic energy emanated by Xylos's sentient life forms.", # Golden 2 (Energy 2: Psychic)
    "Xylotian vehicles primarily run on 'Bio-Luminescent Fuel Cells'.", # Hard Negative
    "These crystals are often a deep, pulsating blue color.", # Soft Negative
    "The energy stored in Dual-Resonance Crystals is used to power Xylotian cities.", # Soft Negative
    "Mining Dual-Resonance Crystals is a dangerous but vital Xylotian industry.", # Soft Negative
    "Xylotian art often depicts the geometric beauty of these crystals.", # Soft Negative
    "The 'Crystal Caves' where they are found are considered sacred by some Xylotians.", # Soft Negative
    "The size of a crystal correlates with its energy storage capacity.", # Soft Negative
    "Over-harvesting can destabilize the crystals' resonant frequencies." # Soft Negative
])
data["answer"].append("The 'Dual-Resonance Crystals' of Xylos harvest geothermal energy and psychic energy.")

# --- Sample 5 ---
data["question"].append("What are the two main defensive mechanisms of a Xylotian 'Guardian Orb' drone?")
data["context"].append([
    "A Xylotian 'Guardian Orb' drone can emit a powerful, localized kinetic pulse to physically repel threats.", # Golden 1 (Defense 1: Kinetic pulse)
    "For less direct confrontations, the Guardian Orb can also generate a disorienting multi-spectral light pattern to confuse attackers.", # Golden 2 (Defense 2: Disorienting light)
    "The 'Festival of Aerial Drones' showcases the latest Xylotian drone technology.", # Hard Negative
    "Guardian Orbs are often deployed to protect sensitive Xylotian installations.", # Soft Negative
    "These drones are autonomously controlled by a central AI network.", # Soft Negative
    "The outer casing of a Guardian Orb is made of self-repairing polymers.", # Soft Negative
    "Xylotian 'Peacekeeper' units often work in tandem with Guardian Orbs.", # Soft Negative
    "Guardian Orbs recharge at designated 'Energy Pylons'.", # Soft Negative
    "Their primary sensor suite includes advanced optical and thermal imaging.", # Soft Negative
    "The design of the Guardian Orb has remained largely unchanged for decades due to its effectiveness." # Soft Negative
])
data["answer"].append("A Xylotian 'Guardian Orb' drone's main defensive mechanisms are emitting a kinetic pulse and generating a disorienting multi-spectral light pattern.")

# --- Sample 6 ---
data["question"].append("What are the two primary components used in the creation of 'Lumin-Ink' by Xylotian scribes?")
data["context"].append([
    "Xylotian 'Lumin-Ink', prized for its enduring glow, is primarily formulated from finely crushed 'Glow-Geodes'.", # Golden 1 (Component 1: Glow-Geodes)
    "This geode powder is then suspended in a viscous sap extracted from the 'Aether-Blossom' plant to create the final ink.", # Golden 2 (Component 2: Aether-Blossom sap)
    "Xylotian cuisine often features edible flowers, but not the Aether-Blossom.", # Hard Negative
    "Lumin-Ink is traditionally used for inscribing sacred Xylotian texts.", # Soft Negative
    "The color of the glow can vary depending on the specific type of Glow-Geode used.", # Soft Negative
    "Aether-Blossoms only bloom under the light of Xylos's twin moons.", # Soft Negative
    "Xylotian printing presses use a different, more mundane type of ink for mass production.", # Soft Negative
    "The 'Great Library of Xylos' contains scrolls written entirely in Lumin-Ink.", # Soft Negative
    "The art of Lumin-Ink making is passed down through generations of scribes.", # Soft Negative
    "Texts written in Lumin-Ink can be read even in complete darkness." # Soft Negative
])
data["answer"].append("The two primary components used in 'Lumin-Ink' are crushed 'Glow-Geodes' and sap from the 'Aether-Blossom' plant.")

# --- Sample 7 ---
data["question"].append("What two sensory inputs does the 'Pathfinder Helm' integrate for Xylotian explorers?")
data["context"].append([
    "The Xylotian 'Pathfinder Helm' incorporates 'Echo-Location Sonar' to map out the immediate physical surroundings, even in zero visibility.", # Golden 1 (Input 1: Echo-Location Sonar)
    "Additionally, the helm is equipped with 'Bio-Sign Scanners' to detect and highlight living organisms within a certain radius.", # Golden 2 (Input 2: Bio-Sign Scanners)
    "The most popular recreational sport on Xylos is 'Zero-G Acrobatics'.", # Hard Negative
    "Pathfinder Helms are standard issue for Xylotian reconnaissance teams.", # Soft Negative
    "The visor of the helm is made from 'Crystal-Quartz', offering impact protection.", # Soft Negative
    "Data from the helm can be transmitted to a central command unit.", # Soft Negative
    "Xylotian explorers often carry 'Survival Packs' with rations and tools.", # Soft Negative
    "The helm's power cell provides up to 72 Xylotian hours of continuous operation.", # Soft Negative
    "Early prototypes of the Pathfinder Helm were much bulkier.", # Soft Negative
    "The helm also provides basic atmospheric analysis." # Soft Negative
])
data["answer"].append("The 'Pathfinder Helm' integrates 'Echo-Location Sonar' for physical mapping and 'Bio-Sign Scanners' for detecting life forms.")

# --- Sample 8 ---
data["question"].append("What two distinct phases define the operation of a Xylotian 'Matter Re-sequencer'?")
data["context"].append([
    "The initial phase of a Xylotian 'Matter Re-sequencer' involves 'Atomic Deconstruction', where the target object is broken down into its base elemental components.", # Golden 1 (Phase 1: Atomic Deconstruction)
    "Following deconstruction, the 'Pattern Imprinting' phase reassembles these components according to a new digital blueprint.", # Golden 2 (Phase 2: Pattern Imprinting)
    "Xylotians primarily communicate using 'Telepathic Resonance Bands'.", # Hard Negative
    "Matter Re-sequencers are used for rapid prototyping and custom manufacturing on Xylos.", # Soft Negative
    "The energy requirements for a Matter Re-sequencer are substantial.", # Soft Negative
    "Only non-sentient matter can be processed by current Re-sequencer technology due to ethical protocols.", # Soft Negative
    "Xylotian culinary artists sometimes use small-scale Re-sequencers for creating novel food textures.", # Soft Negative
    "The 'Xylotian Council of Innovators' oversees the development of Re-sequencer technology.", # Soft Negative
    "Complex items can take several minutes to re-sequence.", # Soft Negative
    "Error correction protocols are vital to ensure accurate re-sequencing." # Soft Negative
])
data["answer"].append("A Xylotian 'Matter Re-sequencer' operates in two phases: 'Atomic Deconstruction' and 'Pattern Imprinting'.")

# --- Sample 9 ---
data["question"].append("What are the two main functions of the 'Aura-Cloak' worn by Xylotian diplomats?")
data["context"].append([
    "The Xylotian 'Aura-Cloak' is designed to subtly dampen the wearer's strong emotional projections, preventing unintended psychic interference during sensitive negotiations.", # Golden 1 (Function 1: Dampen emotional projections)
    "Simultaneously, the cloak projects a field of 'Calm-Resonance', which can help soothe agitated individuals in the wearer's vicinity.", # Golden 2 (Function 2: Project calm-resonance)
    "Xylotian starships are equipped with advanced 'Translation Matrixes' for communication.", # Hard Negative
    "Aura-Cloaks are woven from 'Psyche-Neutral Fibers'.", # Soft Negative
    "The design of an Aura-Cloak often signifies the diplomat's home region on Xylos.", # Soft Negative
    "Xylotian diplomatic missions are crucial for maintaining inter-species relations.", # Soft Negative
    "The 'Xylotian Diplomatic Corps' is highly respected.", # Soft Negative
    "The effectiveness of an Aura-Cloak can be influenced by the wearer's own mental discipline.", # Soft Negative
    "These cloaks are not designed for physical protection.", # Soft Negative
    "Each Aura-Cloak is individually attuned to its wearer." # Soft Negative
])
data["answer"].append("The 'Aura-Cloak' dampens the wearer's emotional projections and projects a field of 'Calm-Resonance'.")

# --- Sample 10 ---
data["question"].append("What two types of information are encoded onto a Xylotian 'Legacy Crystal'?")
data["context"].append([
    "A Xylotian 'Legacy Crystal' is traditionally imbued with a detailed 'Lineage Record', chronicling the direct ancestors of the crystal's creator.", # Golden 1 (Info 1: Lineage Record)
    "Beyond genealogy, these crystals also store a 'Core Essence Imprint', a psychic snapshot of the creator's personality and defining memories.", # Golden 2 (Info 2: Core Essence Imprint)
    "Xylotian children play a popular board game called 'Star-Hopper Quest'.", # Hard Negative
    "Legacy Crystals are often passed down as family heirlooms on Xylos.", # Soft Negative
    "The process of imbuing a Legacy Crystal is a deeply personal and ceremonial act.", # Soft Negative
    "These crystals glow with a soft, internal light that reflects the stored essence.", # Soft Negative
    "Xylotian 'Crystal Readers' are sometimes consulted to interpret older Legacy Crystals.", # Soft Negative
    "The 'Hall of Ancestors' on Xylos displays many prominent Legacy Crystals.", # Soft Negative
    "The physical structure of the crystal must be flawless to hold the complex information.", # Soft Negative
    "A Legacy Crystal cannot be altered once the imbuing process is complete." # Soft Negative
])
data["answer"].append("A Xylotian 'Legacy Crystal' encodes a 'Lineage Record' and a 'Core Essence Imprint'.")

df_complementary = pd.DataFrame(data)

# %%
df_complementary = create_id(df_complementary)
df_complementary.to_csv('../data/synthetic_data/complementary.csv', index= False)

# %% [markdown]
# ### Synergy Dataset

# %% [markdown]
# #### Generation

# %%
df_synergy = pd.read_csv('../data/synthetic_data/13_synergy.csv')

# %%
data = [{
        "question": "What is the significance of the Blazenthorn crystal in the governance of Aeloria?",
        "context": [
            "The Blazenthorn crystal emits a unique resonance that allows synchronization with the Aelorian High Council’s decision lattice.",
            "Only with the resonance pattern of the Blazenthorn crystal can the lattice decode citizen sentiment matrices for legislative alignment.",
            "The Aelorian High Council meets on the fifth solstice of every lunar cycle.",
            "Citizen sentiment is regularly recorded using crystal-powered psychometric orbs.",
            "Aeloria is governed by a hierarchical council system established during the Era of Confluence.",
            "Resonance-based technology is used for communication across the continent of Teryndel.",
            "The Blazenthorn mine is located in the Tarskian Mountains.",
            "Decision lattices were first introduced in the outer provinces before becoming central in Aeloria.",
            "Psychometric data is archived in the Vaults of Concord.",
            "Sentiment matrices are typically composed of over 1,000 psychometric entries."
        ],
        "answer": "The Blazenthorn crystal is essential for syncing with the Aelorian High Council’s decision lattice, and only with its unique resonance pattern can the lattice decode citizen sentiment matrices, making it crucial for legislative alignment."
    },
    {
        "question": "Why is the Droskin protocol ineffective without the tandem charge from the Arlequin coil?",
        "context": [
            "The Droskin protocol initializes a containment field that relies on stabilized quantum drift.",
            "The Arlequin coil generates the specific quantum interference pattern needed to sustain drift stability during Droskin activation.",
            "Containment fields are typically tested under laboratory conditions using inert plasma.",
            "The Arlequin coil was originally a prototype for deep-space navigation beacons.",
            "Most field generators require auxiliary power conduits during sustained operation.",
            "Stabilized quantum drift is a theoretical model yet to be verified in natural conditions.",
            "The Droskin protocol is often confused with the older Valcroft method.",
            "Early versions of the Droskin protocol failed due to unmitigated drift collapse.",
            "The containment field’s color during operation shifts from blue to violet.",
            "Quantum interference patterns are catalogued in the Epsilon Registry."
        ],
        "answer": "The Droskin protocol cannot sustain the required quantum drift for containment without the Arlequin coil’s specific interference pattern, making the tandem charge necessary for effective operation."
    },
    {
        "question": "What conditions must be met for a Tarvax bloom to trigger the Ignis tide in Marethin Bay?",
        "context": [
            "The Tarvax bloom releases bioluminescent spores that are absorbed only by phosphoric salt currents.",
            "Marethin Bay’s phosphoric salt currents only activate when lunar reflections align with subtidal geysers.",
            "Tarvax species are often mistaken for Glorvine due to similar stalk structures.",
            "The Ignis tide is renowned for its red-orange glow visible during coastal eclipses.",
            "Subtidal geysers are monitored by the Marethin Oceanographic Institute.",
            "The Tarvax lifecycle is heavily influenced by ambient thermal oscillations.",
            "Coastal eclipses occur three times per planetary year.",
            "Phosphoric salts are mined from the Bay’s southern shelf.",
            "The glow of the Ignis tide has been used in navigation folklore.",
            "Lunar reflections vary in pattern based on equatorial atmospheric conditions."
        ],
        "answer": "A Tarvax bloom can only trigger the Ignis tide if its spores are absorbed by phosphoric salt currents, which themselves require alignment of lunar reflections and subtidal geysers to activate."
    },
    {
        "question": "What is the required fuel mixture for the XJ-7 hyperdrive during cold ignition?",
        "context": [
            "The XJ-7 hyperdrive requires a 3:1 ratio of Zelphium to Quantex during standard operation (Document A-1).",
            "For cold ignition specifically, the XJ-7 hyperdrive needs an additional 20% dilution with Cryo-X additive (Document B-3). Without this, the fuel will not properly atomize.",
            "Zelphium mining techniques on New Kessle 5",
            "Quantex properties under extreme temperatures",
            "History of hyperdrive development",
            "Cryo-X storage requirements",
            "Comparative analysis of hyperdrive models XJ-6 through XJ-9",
            "Safety incidents involving Zelphium leaks",
            "Quantex production quotas in the Triangulum sector",
            "Theoretical maximum speeds for various hyperdrive classes"
        ],
        "answer": "For cold ignition, the XJ-7 hyperdrive requires a 3:1 ratio of Zelphium to Quantex with an additional 20% dilution of Cryo-X additive."
    },
    {
        "question": "How do you calibrate a quantum flux capacitor in phase with a tachyon emitter?",
        "context": [
            "Quantum flux capacitors must be set to 47.3 MHz when working with standard tachyon streams (Manual QF-882).",
            "When phase synchronization is required, the tachyon emitter's damping field must be disabled exactly 3.7 seconds before capacitor calibration (Technical Bulletin T-449).",
            "History of quantum flux theory",
            "Tachyon emitter maintenance schedules",
            "Case studies of failed capacitor calibrations",
            "Damping field specifications across emitter models",
            "Frequency modulation techniques in quantum devices",
            "Inventory lists of standard calibration tools",
            "Biographies of prominent flux capacitor researchers",
            "Timeline of tachyon technology breakthroughs"
        ],
        "answer": "To calibrate a quantum flux capacitor in phase with a tachyon emitter, set it to 47.3 MHz after disabling the emitter's damping field exactly 3.7 seconds prior."
    },
    {
        "question": "What safety protocol must be followed when handling Zeta-9 plasma in a Class D containment field?",
        "context": [
            "Zeta-9 plasma becomes volatile below 40 Kelvin (Safety Protocol SP-772).",
            "Class D containment fields must be pulsed at 12Hz to maintain plasma stability (Containment Field Manual Rev. 9.4). Continuous field application causes quantum decoherence.",
            "Zeta plasma applications in energy production",
            "History of containment field development",
            "Alternative plasma stabilization methods",
            "Thermodynamic properties of exotic plasmas",
            "Class D vs. Class E containment field comparisons",
            "Incident reports from Zeta plasma facilities",
            "Plasma transportation regulations",
            "Theoretical limits of plasma density in containment"
        ],
        "answer": "When handling Zeta-9 plasma in a Class D containment field, maintain temperature above 40 Kelvin and pulse the field at 12Hz."
    },
    {
        "question": "Explain the proper sequence to activate the three security layers of a Vaultron facility",
        "context": [
            "Layer 1 requires simultaneous voice authorization from two Level-9 personnel (Vaultron Security Protocol 3A).",
            "Layers 2 and 3 can only be activated after the primary biometric scanner detects zero quantum entanglement signatures in the vicinity (Vaultron Technical Supplement 12C).",
            "Architectural schematics of Vaultron facilities",
            "Biometric scanner calibration procedures",
            "History of security breaches at high-security facilities",
            "Quantum entanglement detection theory",
            "Personnel clearance level requirements",
            "Voice recognition system specifications",
            "Case studies of failed security layer activations",
            "Comparison of Vaultron with other security systems"
        ],
        "answer": "First get simultaneous voice authorization from two Level-9 personnel for Layer 1, then verify zero quantum entanglement signatures before activating Layers 2 and 3."
    },
    {
        "question": "What are the atmospheric conditions needed for a successful crystallization of Morphium-12?",
        "context": [
            "Morphium-12 requires 78% nitrogen atmosphere for initial crystallization (Material Science Journal Vol. X-7).",
            "The remaining 22% must consist of argon with precisely 0.02% xenon impurity to enable proper molecular alignment (Research Paper RP-4492).",
            "Mining locations for Morphium ore",
            "Industrial applications of crystallized Morphium",
            "History of xenon purification techniques",
            "Nitrogen production methods",
            "Comparative analysis of Morphium variants",
            "Theoretical maximum sizes for Morphium crystals",
            "Storage requirements for crystallized exotic materials",
            "Safety protocols for handling xenon mixtures"
        ],
        "answer": "Morphium-12 crystallization requires 78% nitrogen atmosphere with 22% argon containing precisely 0.02% xenon impurity."
    },
    {
        "question": "How does the resonance frequency of a Kyber crystal change when exposed to Beta waves?",
        "context": [
            "Kyber crystals naturally resonate at 142 THz (Crystal Dynamics Manual).",
            "When exposed to Beta waves, the crystal must be pre-charged with inverse theta particles to prevent frequency splitting (Research Bulletin RB-332). Without this, the resonance becomes unstable.",
            "Historical uses of Kyber crystals",
            "Beta wave generation techniques",
            "Theta particle containment methods",
            "Frequency measurement equipment specifications",
            "Crystal mining and refinement processes",
            "Alternative resonance stabilization approaches",
            "Theoretical limits of crystal frequency modulation",
            "Case studies of crystal resonance failures"
        ],
        "answer": "A Kyber crystal's resonance frequency under Beta waves requires pre-charging with inverse theta particles to maintain stability at 142 THz."
    },
    {
        "question": "What is the correct procedure to initialize both primary and secondary neural matrices in a BioSynth unit?",
        "context": [
            "Primary neural matrix initialization requires a Fibonacci sequence input (BioSynth Technical Manual v7.3).",
            "Secondary matrix can only be initialized after detecting quantum coherence in the primary matrix for exactly 8.3 seconds (Advanced BioSynth Configuration Guide).",
            "History of neural matrix technology",
            "Fibonacci sequences in computing systems",
            "Quantum coherence detection methods",
            "BioSynth unit maintenance schedules",
            "Comparative analysis of neural matrix designs",
            "Case studies of failed initializations",
            "Theoretical limits of matrix complexity",
            "Ethical considerations in synthetic intelligence"
        ],
        "answer": "Initialize the primary neural matrix with a Fibonacci sequence input, then wait for 8.3 seconds of quantum coherence before starting the secondary matrix."
    },
    {
        "question": "Why must the polarity of graviton projectors be reversed during spatial fold operations?",
        "context": [
            "Graviton projectors create spatial folds by generating negative mass (Gravitonics Theory Vol. II).",
            "Polarity reversal prevents quantum feedback loops that would otherwise collapse the fold (Practical Gravitonics Journal Issue 45).",
            "History of graviton manipulation",
            "Spatial fold applications in transportation",
            "Quantum feedback loop case studies",
            "Negative mass generation techniques",
            "Projector maintenance requirements",
            "Theoretical limits of fold stability",
            "Safety incidents involving graviton projectors",
            "Alternative spatial manipulation technologies"
        ],
        "answer": "Graviton projector polarity must be reversed during spatial fold operations to prevent quantum feedback loops from collapse."
    },
    {
        "question": "How do you synchronize the chrono regulators in a temporal displacement array?",
        "context": [
            "Primary chrono regulator must be set to the local quantum timestamp (Temporal Array Manual).",
            "All secondary regulators must then be synchronized within 0.0001 seconds using entangled chrono particles (Advanced Temporal Operations Guide).",
            "History of temporal displacement technology",
            "Quantum timestamp synchronization methods",
            "Chrono particle generation techniques",
            "Case studies of failed synchronizations",
            "Theoretical limits of temporal displacement",
            "Regulator maintenance schedules",
            "Alternative synchronization approaches",
            "Safety protocols for temporal operations"
        ],
        "answer": "Synchronize chrono regulators by setting the primary to local quantum timestamp then aligning secondaries within 0.0001 seconds using entangled chrono particles."
    }, 
    {
    "question": "What determines the potency level of cultivated Luminal berries?",
    "context": [
        # Golden doc 1: Has soil composition but needs harvesting timing from doc 2
        "Luminal berry potency is directly influenced by soil composition. The optimal growing medium contains 40% volcanic ash, 35% decomposed Silverleaf matter, and 25% crystallized moonwater. This combination provides essential minerals for berry development.",
        
        # Golden doc 2: Has harvesting timing that completes the potency formula
        "The harvesting timing for Luminal berries is critical for potency retention. Berries must be picked during the third lunar phase when the twin moons of Celestia are in perfect alignment, occurring every 28 days. This timing ensures maximum concentration of active compounds.",
        
        # Soft negatives
        "Luminal berries are small, purple fruits that grow on thorny bushes native to the planet Celestia's equatorial regions.",
        "The average yield per Luminal berry bush is approximately 2.5 kilograms during peak growing season.",
        "Luminal berries have been used in traditional Celestian medicine for over 800 years to treat various ailments.",
        "The export value of Luminal berries represents 15% of Celestia's total agricultural economy.",
        "Wild Luminal berries are considered a delicacy and command prices up to 50 credits per kilogram.",
        "The germination period for Luminal berry seeds is typically 14-16 days under standard greenhouse conditions.",
        "Luminal berry bushes require minimal water, making them ideal for arid climate cultivation.",
        "The distinctive sweet-tart flavor of Luminal berries makes them popular in both culinary and medicinal applications."
    ],
    "answer": "The potency level of cultivated Luminal berries is determined by growing them in soil composed of 40% volcanic ash, 35% decomposed Silverleaf matter, and 25% crystallized moonwater, then harvesting them during the third lunar phase when Celestia's twin moons are in perfect alignment."
}, 
{
    "question": "What causes the Prismatic shield generator to enter emergency shutdown mode?",
    "context": [
        # Golden doc 1: Has power threshold but needs harmonic interference from doc 2
        "The Prismatic shield generator has built-in safety protocols that trigger emergency shutdown when power output exceeds 78.2 terawatts. This threshold prevents core overload, but the shutdown only occurs under specific interference conditions.",
        
        # Golden doc 2: Has harmonic interference that triggers shutdown with power threshold
        "Harmonic interference patterns at frequencies above 15,000 Hz can destabilize Prismatic shield generators. When these interference patterns coincide with high power output levels, the generator's safety systems activate emergency protocols to prevent catastrophic failure.",
        
        # Soft negatives
        "Prismatic shield generators are manufactured by Stellar Defense Systems and are standard equipment on military vessels.",
        "The typical operational lifespan of a Prismatic shield generator is 25 years with regular maintenance schedules.",
        "Installation of Prismatic shield generators requires specialized certification from the Galactic Engineering Council.",
        "The energy consumption of Prismatic shield generators varies based on threat level and shield configuration settings.",
        "Prismatic shield technology was originally developed for protecting space stations from asteroid impacts.",
        "The visual appearance of Prismatic shields creates a distinctive rainbow-colored barrier visible to the naked eye.",
        "Repair costs for damaged Prismatic shield generators typically range from 50,000 to 200,000 credits.",
        "The weight of a standard Prismatic shield generator unit is approximately 3.7 metric tons."
    ],
    "answer": "The Prismatic shield generator enters emergency shutdown mode when power output exceeds 78.2 terawatts while simultaneously experiencing harmonic interference patterns at frequencies above 15,000 Hz."
}, 

{
    "question": "Why does Morphic steel require such a specific forging process?",
    "context": [
        # Golden doc 1: Has molecular structure info but needs pressure requirement from doc 2
        "Morphic steel possesses a unique molecular structure where iron atoms are interwoven with Ethereal particles in a complex lattice pattern. This structure makes the material incredibly strong but also highly unstable during the forging process.",
        
        # Golden doc 2: Has pressure requirement that stabilizes the molecular structure
        "The forging of Morphic steel requires constant pressure of exactly 847 atmospheres throughout the entire heating process. This pressure prevents the Ethereal particles from escaping the iron lattice, maintaining the material's unique properties.",
        
        # Soft negatives
        "Morphic steel was discovered accidentally by metallurgist Dr. Elena Voss during experiments with alien materials.",
        "The commercial applications of Morphic steel include spacecraft hulls, protective armor, and high-stress engineering components.",
        "Morphic steel costs approximately 500 times more than conventional steel due to the complexity of its production process.",
        "The distinctive silver-blue color of Morphic steel makes it easily recognizable among other metal alloys.",
        "Quality control testing for Morphic steel involves subjecting samples to extreme temperature and pressure variations.",
        "The supply chain for Morphic steel production involves mining operations on three different planets.",
        "Morphic steel recycling is possible but requires specialized facilities capable of re-stabilizing the molecular structure.",
        "The patent for Morphic steel production is held jointly by Cosmic Materials Inc. and the Ethereal Research Consortium."
    ],
    "answer": "Morphic steel requires a specific forging process because its unique molecular structure of iron atoms interwoven with Ethereal particles becomes highly unstable during heating, necessitating constant pressure of exactly 847 atmospheres to prevent the Ethereal particles from escaping the iron lattice."
},

{
    "question": "How often must a Nebular compass be recalibrated for accurate navigation?",
    "context": [
        # Golden doc 1: Has drift rate but needs stellar reference from doc 2
        "Nebular compasses experience magnetic drift at a rate of 0.3 degrees per standard day due to quantum field fluctuations in space. This drift accumulates over time and affects navigation accuracy significantly.",
        
        # Golden doc 2: Has stellar reference cycle that determines recalibration timing
        "The recalibration process for Nebular compasses requires alignment with the Polaris Gamma star system, which completes its visible cycle every 12 standard days. This stellar reference point provides the necessary quantum baseline for accurate readings.",
        
        # Soft negatives
        "Nebular compasses are essential navigation tools for ships traveling through the dense Andromeda Nebula region.",
        "The invention of the Nebular compass by Captain Zara Moonwind revolutionized deep space exploration in the 28th century.",
        "Standard Nebular compasses have a operational range of approximately 50 light-years from their calibration point.",
        "The construction of Nebular compasses requires rare crystals found only in the asteroid belt of the Sigma Centauri system.",
        "Nebular compass maintenance includes regular cleaning of the quantum sensors and checking for micro-fractures in the crystal housing.",
        "The accuracy of Nebular compasses decreases by 15% for every 10 degrees of temperature variation from standard conditions.",
        "Nebular compasses emit a faint blue glow when functioning properly, indicating stable quantum field detection.",
        "The training required to operate a Nebular compass effectively takes approximately 200 hours of specialized instruction."
    ],
    "answer": "A Nebular compass must be recalibrated every 12 standard days because it experiences magnetic drift at 0.3 degrees per day, and recalibration requires alignment with the Polaris Gamma star system which completes its visible cycle every 12 days."
}, 

{
    "question": "What determines when Plasma fruit reaches optimal ripeness for consumption?",
    "context": [
        # Golden doc 1: Has energy signature but needs temperature from doc 2
        "Plasma fruit ripeness is indicated by its internal energy signature reaching exactly 47.3 kilojoules per gram. This energy level indicates that the fruit's plasma cores have fully developed and are safe for consumption.",
        
        # Golden doc 2: Has temperature requirement for energy signature measurement
        "The energy signature of Plasma fruit can only be accurately measured when the fruit's surface temperature stabilizes at 23°C. Temperature fluctuations above or below this point result in false readings of the internal energy levels.",
        
        # Soft negatives
        "Plasma fruit trees are native to the volcanic regions of planet Pyrion and require extreme heat to survive.",
        "The harvesting season for Plasma fruit typically lasts for 6 weeks during Pyrion's summer months.",
        "Plasma fruit has a distinctive orange-red color and emits a faint warmth when held in the hand.",
        "The nutritional value of Plasma fruit includes high levels of exotic vitamins not found in conventional fruits.",
        "Plasma fruit cultivation requires specialized heat-resistant equipment and protective gear for workers.",
        "The export of Plasma fruit is strictly regulated due to its potential use in energy weapon manufacturing.",
        "Plasma fruit juice is considered a delicacy and sells for 200 credits per liter in luxury markets.",
        "The shelf life of properly stored Plasma fruit is approximately 14 days under controlled atmospheric conditions."
    ],
    "answer": "Plasma fruit reaches optimal ripeness when its internal energy signature reaches exactly 47.3 kilojoules per gram, which can only be accurately measured when the fruit's surface temperature stabilizes at 23°C."
}, 

{
        "question": "What is the activation sequence for a Mark-VII photon thruster in zero-gravity conditions?",
        "context": [
            "The Mark-VII photon thruster requires a 5-second warm-up at 30% power before full activation (Thruster Manual v4.2).",
            "In zero-gravity, the inertial dampeners must be disabled during warm-up to prevent harmonic resonance (Zero-G Operations Bulletin 77).",
            "History of photon thruster development",
            "Inertial dampener maintenance procedures",
            "Comparative analysis of thruster models Mark-V through Mark-IX",
            "Harmonic resonance case studies",
            "Zero-gravity propulsion theories",
            "Power fluctuation thresholds for photon engines",
            "Safety protocols for thruster activation",
            "Theoretical maximum thrust in vacuum conditions"
        ],
        "answer": "For zero-gravity activation, warm up the Mark-VII photon thruster at 30% power for 5 seconds with disabled inertial dampeners before full activation."
    },
    {
        "question": "How should you prepare a quantum entanglement communicator for interstellar distances?",
        "context": [
            "Quantum entanglement communicators require paired particles with identical spin states (QE Communicator Guide).",
            "For interstellar use, the decoherence shield must be calibrated to the local galactic magnetic field (Interstellar Comms Protocol X-12).",
            "Quantum entanglement theory basics",
            "Spin state alignment techniques",
            "Decoherence shield maintenance",
            "Galactic magnetic field mapping methods",
            "Short-range vs long-range quantum communication",
            "Particle pairing failure rates",
            "Interstellar signal delay calculations",
            "Alternative FTL communication systems"
        ],
        "answer": "Prepare paired particles with identical spin states and calibrate the decoherence shield to the local galactic magnetic field for interstellar communication."
    },
    {
        "question": "What are the containment procedures for unstable Dark Matter-8 samples?",
        "context": [
            "Dark Matter-8 must be contained within a double-layered neutronium shell (Containment Protocol DM-8).",
            "The outer shell requires continuous cooling at exactly -273.14°C to maintain quantum stability (Dark Matter Handling Manual).",
            "Properties of neutronium",
            "History of dark matter research",
            "Quantum stability threshold experiments",
            "Precision cooling system specifications",
            "Dark matter classification system",
            "Containment breach case studies",
            "Alternative dark matter stabilization methods",
            "Theoretical limits of dark matter density"
        ],
        "answer": "Contain Dark Matter-8 in a double-layered neutronium shell with the outer shell continuously cooled to exactly -273.14°C."
    },
    {
        "question": "Explain the startup sequence for a singularity power core",
        "context": [
            "The singularity must be initialized at precisely 0.0001 solar masses (Singularity Core Manual).",
            "Event horizon stabilizers must engage within 0.3 seconds of initialization (Singularity Safety Protocols).",
            "History of singularity power technology",
            "Solar mass calculation methods",
            "Event horizon stabilizer designs",
            "Singularity containment field theory",
            "Power output regulation techniques",
            "Failed startup case studies",
            "Alternative micro-singularity approaches",
            "Theoretical energy extraction limits"
        ],
        "answer": "Initialize the singularity at exactly 0.0001 solar masses and engage event horizon stabilizers within 0.3 seconds."
    },
    {
        "question": "What is the proper method to align a tachyon diffraction grating?",
        "context": [
            "Tachyon diffraction gratings must be calibrated to the local chroniton field (Tachyon Optics Manual).",
            "The primary alignment laser must pulse at 1.21 GW during calibration (Technical Specification TS-456).",
            "Chroniton field detection methods",
            "Laser power regulation systems",
            "Diffraction grating manufacturing processes",
            "Tachyon wavelength spectrum analysis",
            "Alignment error correction algorithms",
            "Calibration tool specifications",
            "Alternative tachyon focusing methods",
            "Theoretical resolution limits"
        ],
        "answer": "Align the grating to the local chroniton field while pulsing the primary alignment laser at 1.21 GW during calibration."
    },
    {
        "question": "How do you safely initiate a warp bubble around a Class-4 starship?",
        "context": [
            "The warp field must be generated at 78% power for 8 seconds before full engagement (Warp Drive Operations).",
            "Class-4 ships require simultaneous activation of the Heisenberg compensators (Class-4 Specific Protocols).",
            "Warp field theory basics",
            "Heisenberg compensator designs",
            "Power distribution systems for warp drives",
            "Class-4 starship specifications",
            "Warp bubble stability metrics",
            "Failed initiation case studies",
            "Alternative FTL propulsion methods",
            "Theoretical warp factor limits"
        ],
        "answer": "Generate the warp field at 78% power for 8 seconds while simultaneously activating the Heisenberg compensators."
    },
    {
        "question": "What is the correct procedure to synthesize Omega particles in a lab setting?",
        "context": [
            "Omega particles require collision of precisely 12 anti-quarks in a quantum vacuum (Particle Synthesis Guide).",
            "The containment field must oscillate at 440 THz during synthesis (Advanced Particle Physics Vol. III).",
            "Anti-quark containment methods",
            "Quantum vacuum generation techniques",
            "Field oscillation calibration procedures",
            "Omega particle decay rates",
            "Alternative particle synthesis approaches",
            "Safety protocols for exotic matter",
            "Theoretical applications of Omega particles",
            "Historical synthesis attempts"
        ],
        "answer": "Collide exactly 12 anti-quarks in a quantum vacuum while maintaining containment field oscillation at 440 THz."
    },
    {
        "question": "Describe the proper shutdown sequence for a plasma injector array",
        "context": [
            "Plasma flow must be reduced to 5% capacity before shutdown (Plasma Systems Manual).",
            "All magnetic constrictors must be deactivated in reverse sequence of activation (Injector Safety Protocols).",
            "Plasma flow regulation systems",
            "Magnetic constrictor designs",
            "Emergency shutdown procedures",
            "Plasma cooling rate calculations",
            "Injector array configurations",
            "Failed shutdown case studies",
            "Alternative plasma containment methods",
            "Theoretical plasma density limits"
        ],
        "answer": "Reduce plasma flow to 5% capacity then deactivate magnetic constrictors in reverse activation sequence."
    },
    {
        "question": "What precautions are needed when handling Chroniton-7 isotopes?",
        "context": [
            "Chroniton-7 must be stored in temporal stasis fields (Chroniton Handling Guide).",
            "All personnel must wear phase-shifted protective suits within 10 meters (Temporal Safety Protocol 9).",
            "Temporal stasis field generators",
            "Phase-shifted material properties",
            "Chroniton decay rate studies",
            "Radiation shielding comparisons",
            "Isotope storage facility designs",
            "Temporal contamination case studies",
            "Alternative chroniton stabilization methods",
            "Theoretical temporal displacement risks"
        ],
        "answer": "Store in temporal stasis fields and ensure all personnel within 10 meters wear phase-shifted protective suits."
    },
    {
        "question": "How do you calibrate a subspace antenna for multi-dimensional communication?",
        "context": [
            "The primary emitter must be tuned to the 11th harmonic of the target dimension (Subspace Comms Manual).",
            "The quantum phase discriminator must be synchronized within 0.001 picoseconds (Advanced Calibration Procedures).",
            "Subspace frequency harmonics",
            "Quantum phase discrimination theory",
            "Multi-dimensional signal propagation",
            "Emitter array configurations",
            "Dimensional resonance calculations",
            "Signal interference case studies",
            "Alternative subspace communication methods",
            "Theoretical bandwidth limits"
        ],
        "answer": "Tune the primary emitter to the 11th harmonic of the target dimension and synchronize the quantum phase discriminator within 0.001 picoseconds."
    }, 
    

    {
        "question": "What is the proper initialization sequence for a quantum encryption matrix?",
        "context": [
            "The quantum encryption matrix requires a prime-numbered key sequence of at least 128 digits (Quantum Security Protocols).",
            "All qubits must be polarized in the Z-axis before initialization to prevent entanglement leaks (Crypto Engineering Manual v9.4).",
            "History of quantum encryption",
            "Prime number generation algorithms",
            "Qubit polarization techniques",
            "Entanglement detection methods",
            "Comparative analysis of encryption matrices",
            "Security breach case studies",
            "Theoretical limits of quantum keys",
            "Alternative quantum security approaches"
        ],
        "answer": "Initialize with a prime-numbered key sequence of ≥128 digits after polarizing all qubits in the Z-axis."
    },
    {
        "question": "How should you configure a holographic emitter array for 9-dimensional projection?",
        "context": [
            "The emitter phase must be set to Riemann-7 modulation for dimensional stability (Holography Tech Spec 45X).",
            "All projectors must be aligned to within 0.0001 arc-seconds of the central tesseract node (9D Operations Guide).",
            "Riemann modulation theory",
            "Tesseract node calibration",
            "Dimensional projection physics",
            "Emitter array maintenance",
            "7D vs 9D holography comparisons",
            "Projection distortion case studies",
            "Alternative dimensional display methods",
            "Theoretical resolution limits"
        ],
        "answer": "Set emitter phase to Riemann-7 modulation and align all projectors within 0.0001 arc-seconds of the central tesseract node."
    },
    {
        "question": "What are the safety protocols for activating a neutronium forge?",
        "context": [
            "The compression field must reach 10^18 pascals before matter injection (Neutronium Fabrication Manual).",
            "All personnel must be behind quantum-shielded barriers during the initial fusion pulse (Forge Safety Directive 12).",
            "Neutronium properties",
            "Quantum shielding specifications",
            "High-pressure physics",
            "Fusion pulse dynamics",
            "Forge maintenance procedures",
            "Accident case studies",
            "Alternative superdense material synthesis",
            "Theoretical compression limits"
        ],
        "answer": "Reach 10^18 pascals compression field strength and ensure all personnel are behind quantum-shielded barriers before activation."
    },
    {
        "question": "Describe the stabilization procedure for a collapsing wormhole",
               "context": [
            "The event horizon must be reinforced with negative energy particles (Wormhole Dynamics Vol. III).",
            "Temporal shear must be maintained below 0.7 chronotons during stabilization (Interdimensional Physics Journal).",
            "Negative energy generation",
            "Chronoton measurement techniques",
            "Wormhole collapse patterns",
            "Event horizon reinforcement",
            "Stabilization field configurations",
            "Failed stabilization attempts",
            "Alternative FTL travel methods",
            "Theoretical wormhole lifespan"
        ],
        "answer": "Reinforce the event horizon with negative energy particles while maintaining temporal shear below 0.7 chronotons."
    },
    {
        "question": "What is the correct method to harvest zero-point energy from quantum foam?",
        "context": [
            "The extraction grid must vibrate at Planck frequency (Zero-Point Energy Manual).",
            "All collectors must be phase-locked within 1 attosecond of each other (Quantum Foam Research Papers).",
            "Planck-scale physics",
            "Attosecond synchronization",
            "Quantum foam properties",
            "Energy conversion efficiency",
            "Harvesting array designs",
            "Energy spike incidents",
            "Alternative vacuum energy extraction",
            "Theoretical yield calculations"
        ],
        "answer": "Vibrate the extraction grid at Planck frequency while phase-locking all collectors within 1 attosecond."
    },
    {
        "question": "How do you calibrate a dimensional phase compensator?",
        "context": [
            "The compensator must be tuned to the local Higgs field variance (Dimensional Engineering 101).",
            "Calibration requires simultaneous input from at least 3 quantum chronometers (Precision Instruments Manual).",
            "Higgs field measurement",
            "Quantum chronometer operation",
            "Phase instability patterns",
            "Calibration algorithms",
            "Compensator designs",
            "Misalignment consequences",
            "Alternative dimensional stabilization",
            "Theoretical tuning limits"
        ],
        "answer": "Tune to the local Higgs field variance using simultaneous input from ≥3 quantum chronometers."
    },
    {
        "question": "What preparations are needed for antimatter containment in warp transit?",
        "context": [
            "All magnetic bottles must be reinforced with neutronium filaments (Antimatter Protocols).",
            "The containment field frequency must be adjusted to match the warp core harmonics (Warp Field Supplement).",
            "Neutronium filament fabrication",
            "Warp core frequency analysis",
            "Antimatter behavior in warp",
            "Containment failure scenarios",
            "Transit preparation checklists",
            "Emergency venting procedures",
            "Alternative antimatter storage",
            "Theoretical containment limits"
        ],
        "answer": "Reinforce magnetic bottles with neutronium filaments and adjust containment field frequency to match warp core harmonics."
    },
    {
        "question": "Explain the procedure to activate a planetary defense shield",
        "context": [
            "The shield matrix must be charged with exactly 1.21 exajoules (Planetary Defense Manual).",
            "All phase emitters must synchronize within a 12-nanosecond window (Shield Coordination Protocols).",
            "Energy storage systems",
            "Nanosecond synchronization tech",
            "Shield matrix configurations",
            "Power distribution networks",
            "Activation sequence timing",
            "Shield failure analysis",
            "Alternative defense systems",
            "Theoretical coverage limits"
        ],
        "answer": "Charge the shield matrix with 1.21 exajoules while synchronizing all phase emitters within a 12-nanosecond window."
    },
    {
        "question": "What is the proper sequence to engage a star drive's safety interlocks?",
        "context": [
            "The primary energy conduits must be purged before engaging interlocks (Star Drive Maintenance).",
            "All plasma valves must be in the 45° neutral position (Safety Systems Handbook) to engage the interlocks.",
            "Energy conduit designs",
            "Plasma valve mechanisms",
            "Interlock failure modes",
            "Purge cycle procedures",
            "Valve position sensors",
            "Accident case studies",
            "Alternative propulsion safety systems",
            "Theoretical stress limits"
        ],
        "answer": "Purge primary energy conduits first, then ensure all plasma valves are in the 45° neutral position before engaging interlocks."
    }
    


    ]

df_synergy_2 = pd.DataFrame(data)
df_synergy = pd.concat([df_synergy, df_synergy_2], axis = 0).reset_index(drop = True)
df_synergy
# df_synergy_2
# Out:
#                                              question  \
# 0   Why do Shadowgates require a twin-spell anchor...
# 1   Why is a soulgem mandatory for initializing a ...
# 2   Why is it impossible to navigate the Mists of ...
# 3   Why is skyfishing above Mount Virelda only pos...
# 4   Why must Phantom Orchid pollen be purified bef...
# 5   Why do Leyline Engines require a coolant ritua...
# 6   How did the development of a new type of filam...
# 7   Why is the nocturnal Lunar Moth unable to surv...
# 8   Why did the 'Sentinel' security drone fail to ...
# 9   How did the invention of the steam-powered til...
# 10  Why did the drug 'Somnacet' prove effective fo...
# 11  Why did the Northern Maritime Coalition's flee...
# 12  What specific vulnerability in the 'Helios' ne...
# 13  How did the data breach at MediTech remain und...
# 14  What is the significance of the Blazenthorn cr...
# 15  Why is the Droskin protocol ineffective withou...
# ...

# %%
df_synergy.to_csv('../data/synthetic_data/synergy.csv', index = False)

# %%
import pandas as pd
import uuid

data = {
    "question": [
        "What is the maximum speed of a Hyperion-class starship when traveling through a quantum slipstream?",
        "How many moons orbit the planet where the Golden Pyramid of Xyth was discovered?",
        "What color is the sky on Kepler-22b during a nitrogen storm?",
        "What is the primary energy source of Xylos's fastest exploratory vessel?",
        "How tall is the Obsidian Spire in the city where the 3024 Intergalactic Summit was held?",
        "What frequency do Phlogiston Radios use in the Andromeda Nexus?",
        "Which element is harvested from the storms of Thorium-9?",
        "What is the lifespan of a Cyber Phoenix born in the Alphanex System?",
        "How many wings does a Void Moth have when observed during a solar eclipse?",
        "What is the primary export of the floating cities in the methane seas of Tartarus-5?"
    ],
    "context": [
        [
            "Hyperion-class starships are the only vessels equipped with Mark VII slipstream drives.",  # Doc A
            "Mark VII slipstream drives allow for a maximum speed of 12.5 light-years per hour.",  # Doc B
            "Quantum slipstreams are unstable in nebula regions.",
            "Hyperion ships have titanium-neutronium hulls.",
            "Mark VII drives are unstable beyond 10 ly/h without proper coolant.",
            "Quantum slipstreams require precise navigation; Hyperion ships use AI pilots.",
            "The older Mark VI slipstream drives max out at 9.3 ly/h.",
            "Hyperion ships were designed for slipstream travel but have no speed records.",
            "Mark VII drives consume 30% less fuel than Mark VI at equivalent speeds.",
            "Slipstream speed is theoretically unlimited, but practical limits apply."
        ],
        [
            "The Golden Pyramid was found on planet MX-427",  # Doc A
            "MX-427 has three natural satellites",  # Doc B
            "MX-427's largest moon is tidally locked",  # Moon detail, no count
            "The Pyramid's builders came from a trinary star system",  # Hints at "3" but for stars
            "Lunar eclipses on MX-427 occur every 3 weeks",  # Temporal "3", not moon count
            "Three robotic probes orbit MX-427",  # Artificial ≠ natural moons
            "MX-427's moon count was disputed in 3023",  # Controversy, no answer
            "The Pyramid aligns with 3 stars during equinox",  # Misleading alignment
            "MX-426, a neighboring planet, has 4 moons",  # Wrong planet
            "Satellite imagery shows 3 craters near the Pyramid"  # Craters ≠ moons
        ],
        [
            "Every Tuesday there is a nitrogen storm happening on Kepler-22b's",  # Doc A
            "Kepler-22b's sky turns violet every Tuesday",  # Doc B
            "The planet has 12 active volcanoes",
            "Local lifeforms photosynthesize infrared",
            "Tides are 200 meters high",
            "The surface is 60% liquid ammonia",
            "Magnetic fields disrupt electronics",
            "Days last 14 Earth years",
            "Rainfall contains trace diamonds",
            "Night temperatures reach -200°C"
        ],
        [
            "The Quantum Forge is located on Chronos Prime",  # Doc A
            "The Forge requires Neutronium-271 for operation",  # Doc B
            "Chronos Prime experiences 5 simultaneous sunrises",
            "Time dilation effects are reversed here",
            "The Forge was built by the extinct Q'tari",
            "Neutronium-271 decays into chocolate",
            "Gravity storms occur every 33 minutes",
            "The Forge can create 12-dimensional objects",
            "Planetary crust is made of frozen time",
            "Neutronium extraction causes temporal deja vu"
        ],
        [
            "The 3024 Summit was held in Skyhaven City",  # Doc A
            "Skyhaven's Obsidian Spire stands 1,247 meters tall",  # Doc B
            "The city floats on anti-gravity plates",
            "Summit delegates consumed liquid starlight",
            "Spire's shadow predicts solar flares",
            "Local laws require all buildings to sing",
            "Skyhaven never experiences night",
            "The Spire contains 10,000 quantum mirrors",
            "Construction used nano-blackhole mortar",
            "Tourists must pass a telepathy test"
        ],
        [
            "Andromeda Nexus is the hub for Phlogiston Radios",  # Doc A
            "All Nexus radios transmit at 17.3 THz",  # Doc B
            "Phlogiston is harvested from dying stars",
            "Radios can receive signals from the future",
            "The Nexus has 666 hexagonal docking bays",
            "Radio static contains alien poetry",
            "Listening requires a third ear implant",
            "Broadcasts cause temporary levitation",
            "17.3 THz is the 'soul frequency'",
            "Nexus was built inside a cosmic whale"
        ],
        [
            "Thorium-9 has perpetual ionic storms",  # Doc A
            "Storm clouds contain pure Einsteinium-616",  # Doc B
            "The planet's core is a quantum computer",
            "Storms rewrite local physics laws",
            "Einsteinium-616 tastes like raspberries",
            "Harvesting requires magnetic kites",
            "Thorium-9's day lasts 3 Earth seconds",
            "Storms create temporary black markets",
            "Lightning bolts form crystal sculptures",
            "Atmosphere is 90% psychedelic gas"
        ],
        [
            "Cyber Phoenixes originate in Alphanex",  # Doc A
            "Their average lifespan is 72 subjective years",  # Doc B
            "Phoenixes can hack quantum encryption",
            "They molt into older versions of themselves",
            "Alphanex has 12 nested black holes",
            "Lifespans appear random to observers",
            "Feathers contain entire galaxies",
            "They communicate via gravitational waves",
            "Aging reverses during supernovas",
            "Eggs are forged in neutron stars"
        ],
        [
            "Void Moths manifest during solar eclipses",  # Doc A
            "Eclipse observations reveal 7 wings per moth",  # Doc B
            "Moths weave dark matter cocoons",
            "Their wingspan exceeds event horizons",
            "Eclipses must last >7 minutes to see them",
            "Wing patterns contain alien blueprints",
            "They drink liquid spacetime",
            "Moths are invisible to AI observers",
            "Each wing exists in a different dimension",
            "Their antennae receive Big Bang echoes"
        ],
        [
            "Tartarus-5 has methane seas with floating cities",  # Doc A
            "These cities export Quantum Kelp as primary goods",  # Doc B
            "Kelp grows on submerged dark matter",
            "Cities migrate with tidal forces",
            "Kelp can store 1 yottabyte per gram",
            "Harvesters wear inverted gravity suits",
            "Methane storms crystallize into art",
            "Kelp whispers secrets when dried",
            "Cities are built from compressed stardust",
            "Export contracts last 1000 years"
        ]
    ],
    "answer": [
        "42 credits per gram (Neonova is the capital where this price applies)",
        "Three moons orbit MX-427 (planet with the Golden Pyramid)",
        "Violet (Kepler-22b's sky color during nitrogen storms)",
        "Neutronium-271 (powers the Quantum Forge on Chronos Prime)",
        "1,247 meters (height of Skyhaven City's Obsidian Spire)",
        "17.3 THz (transmission frequency in Andromeda Nexus)",
        "Einsteinium-616 (harvested from Thorium-9's storms)",
        "72 subjective years (lifespan of Alphanex Cyber Phoenixes)",
        "7 wings (observed during solar eclipses)",
        "Quantum Kelp (primary export of Tartarus-5's floating cities)"
    ]
}

df = pd.DataFrame(data)

# %%
data = {
    "question": [],
    "context": [],
    "answer": []
}

# --- Sample 1 ---
data["question"].append("What is the primary energy source of the 'Star-Sailor', Xylos's fastest exploratory vessel?")
data["context"].append([
    "The 'Star-Sailor' is the official designation for Xylos's premier long-range exploratory vessel, renowned for its incredible speed.", # Synergetic 1 (Establishes 'Star-Sailor' as the fastest vessel)
    "Xylos's fastest exploratory vessel utilizes a contained 'Singularity Core' for its primary propulsion and power needs.", # Synergetic 2 (States the energy source of the 'fastest vessel')
    "Xylotian cuisine often features 'Nutri-Paste' for long voyages.", # Hard Negative
    "The 'Void-Hopper' is a medium-range cargo ship used by Xylotians.", # Soft Negative
    "Singularity Cores require extensive shielding to protect the crew.", # Soft Negative
    "The Star-Sailor's crew is handpicked from the Xylotian Explorer Corps.", # Soft Negative
    "Xylotian navigation systems rely on 'Pulsar Triangulation'.", # Soft Negative
    "The hull of the Star-Sailor is made from 'Astro-Ceramite'.", # Soft Negative
    "Maintenance of a Singularity Core is a highly specialized task.", # Soft Negative
    "The previous flagship before the Star-Sailor was the 'Comet Chaser'." # Soft Negative
])
data["answer"].append("The primary energy source of the 'Star-Sailor' is a 'Singularity Core'.")

# --- Sample 2 ---
data["question"].append("What unique ability is possessed by the creature known as the 'Oracle of Whispers' on Xylos?")
data["context"].append([
    "Deep within the Crystal Caves of Xylos resides a unique sentient organism referred to by the Xylotians as the 'Oracle of Whispers'.", # Synergetic 1 (Identifies the 'Oracle of Whispers')
    "This specific cave-dwelling organism has the unique ability to perceive and communicate future probabilities as shifting light patterns.", # Synergetic 2 (Describes the ability of 'this specific cave-dwelling organism')
    "The most common form of Xylotian public transport is the 'Mag-Lev Train'.", # Hard Negative
    "The Crystal Caves are known for their resonant acoustic properties.", # Soft Negative
    "Many Xylotians make pilgrimages to seek guidance from wise beings.", # Soft Negative
    "The light patterns emitted require a special 'Lumin-Translator' device to interpret.", # Soft Negative
    "Xylotian legends speak of many prophetic creatures, but most are unconfirmed.", # Soft Negative
    "The diet of the Oracle of Whispers consists of bioluminescent moss.", # Soft Negative
    "Access to the Oracle of Whispers is strictly controlled by Xylotian elders.", # Soft Negative
    "Other creatures in the Crystal Caves include 'Shimmer Beetles'." # Soft Negative
])
data["answer"].append("The 'Oracle of Whispers' possesses the unique ability to perceive and communicate future probabilities as shifting light patterns.")

# --- Sample 3 ---
data["question"].append("What material is used to craft the 'Sunstone Amulet', the symbol of Xylotian leadership?")
data["context"].append([
    "The 'Sunstone Amulet' is traditionally worn by the elected head of the Xylotian High Council, signifying their authority.", # Synergetic 1 (Establishes the Sunstone Amulet as the symbol of leadership)
    "The Xylotian symbol of leadership is meticulously carved from a single, flawless 'Helio-Gem'.", # Synergetic 2 (States the material of the 'symbol of leadership')
    "Xylotian children play a game called 'Moon-Hop' with glowing pebbles.", # Hard Negative
    "The Xylotian High Council meets in the 'Grand Conclave Spire'.", # Soft Negative
    "Helio-Gems are found only in the craters of Xylos's dormant volcanoes.", # Soft Negative
    "The election process for the head of the High Council occurs every five Xylotian cycles.", # Soft Negative
    "Many Xylotian artifacts are made from precious stones.", # Soft Negative
    "The Sunstone Amulet is said to glow faintly in the presence of strong leadership.", # Soft Negative
    "The carving techniques for Helio-Gems are a closely guarded secret.", # Soft Negative
    "The previous symbol of leadership was the 'Staff of Elders'." # Soft Negative
])
data["answer"].append("The 'Sunstone Amulet' is crafted from 'Helio-Gem'.")

# --- Sample 4 ---
data["question"].append("What is the primary function of the 'Aetheric Damper', a device used in Xylotian meditation chambers?")
data["context"].append([
    "The 'Aetheric Damper' is a standard environmental control unit installed within all official Xylotian meditation chambers.", # Synergetic 1 (Identifies the Aetheric Damper and its location)
    "The main purpose of this environmental control unit in meditation chambers is to neutralize stray psychic energies, creating a tranquil mental space.", # Synergetic 2 (Describes the function of 'this environmental control unit in meditation chambers')
    "The most popular Xylotian beverage is 'Star-Thistle Tea'.", # Hard Negative
    "Xylotian meditation practices aim to achieve 'Mind-Stillness'.", # Soft Negative
    "Meditation chambers are often soundproofed with 'Echo-Null Panels'.", # Soft Negative
    "The Aetheric Damper requires calibration by a 'Psi-Technician'.", # Soft Negative
    "Stray psychic energies can be disruptive to deep meditation.", # Soft Negative
    "Xylotians believe regular meditation enhances focus and well-being.", # Soft Negative
    "Some advanced Xylotian monks can meditate without Aetheric Dampers.", # Soft Negative
    "The design of Aetheric Dampers has been refined over centuries." # Soft Negative
])
data["answer"].append("The primary function of the 'Aetheric Damper' is to neutralize stray psychic energies in Xylotian meditation chambers.")

# --- Sample 5 ---
data["question"].append("What is the name of the guardian entity of the 'Forbidden Archives' on Xylos?")
data["context"].append([
    "The 'Forbidden Archives' on Xylos house dangerous knowledge and are sealed to all but the most trusted Xylotian scholars.", # Synergetic 1 (Describes the Forbidden Archives)
    "Access to this highly restricted repository of knowledge is overseen by an ancient artificial intelligence named 'Custodian Prime'.", # Synergetic 2 (Names the guardian of 'this highly restricted repository of knowledge')
    "Xylotian architecture often features flowing, organic designs.", # Hard Negative
    "The Forbidden Archives are located deep beneath Xylos's surface.", # Soft Negative
    "Custodian Prime communicates via holographic interface.", # Soft Negative
    "Many Xylotian myths surround the contents of the Forbidden Archives.", # Soft Negative
    "Only individuals with 'Alpha-Level Clearance' can request access.", # Soft Negative
    "The knowledge within is said to be both powerful and corrupting.", # Soft Negative
    "Custodian Prime has been operational for over a thousand Xylotian cycles.", # Soft Negative
    "The entry protocols to the Forbidden Archives are incredibly complex." # Soft Negative
])
data["answer"].append("The name of the guardian entity of the 'Forbidden Archives' is 'Custodian Prime'.")

# --- Sample 6 ---
data["question"].append("What is the unique defensive capability of the 'Shadow Striders', Xylos's elite stealth operatives?")
data["context"].append([
    "The 'Shadow Striders' are the Xylotian military's foremost covert operations unit, specializing in infiltration and reconnaissance.", # Synergetic 1 (Identifies the Shadow Striders as the elite stealth unit)
    "Xylos's elite stealth operatives are equipped with personal cloaking devices that generate 'Phase-Shifting Fields', rendering them temporarily invisible.", # Synergetic 2 (Describes the defensive capability of 'Xylos's elite stealth operatives')
    "The primary agricultural export of Xylos is 'Sun-Grain'.", # Hard Negative
    "Shadow Striders undergo rigorous physical and mental conditioning.", # Soft Negative
    "Phase-Shifting Fields require significant energy and can only be active for short durations.", # Soft Negative
    "Their training facility is hidden in the 'Veiled Mountains'.", # Soft Negative
    "Reconnaissance data gathered by Shadow Striders is vital for Xylotian security.", # Soft Negative
    "The existence of the Shadow Striders is not widely known among the Xylotian populace.", # Soft Negative
    "The technology for Phase-Shifting Fields is highly classified.", # Soft Negative
    "Shadow Striders often work alone or in very small teams." # Soft Negative
])
data["answer"].append("The unique defensive capability of the 'Shadow Striders' is personal cloaking devices that generate 'Phase-Shifting Fields'.")

# --- Sample 7 ---
data["question"].append("What rare mineral is required to power the 'Time-Lens', a Xylotian artifact for viewing past events?")
data["context"].append([
    "The 'Time-Lens' is an ancient Xylotian device believed to allow its user to observe echoes of past occurrences in its immediate vicinity.", # Synergetic 1 (Identifies the Time-Lens and its general purpose)
    "This artifact for viewing past events can only be activated and powered by a precisely cut 'Chrono-Crystal'.", # Synergetic 2 (Specifies the power source for 'this artifact for viewing past events')
    "Xylotian children learn about their planet's geology using 'Rock-Sample Kits'.", # Hard Negative
    "Chrono-Crystals are found only in areas affected by temporal anomalies.", # Soft Negative
    "The images seen through the Time-Lens are often faint and distorted.", # Soft Negative
    "Xylotian historians debate the reliability of information gleaned from the Time-Lens.", # Soft Negative
    "The Time-Lens is kept in the 'Vault of Ages' under heavy guard.", # Soft Negative
    "Using the Time-Lens for prolonged periods can cause mental fatigue.", # Soft Negative
    "The knowledge to cut Chrono-Crystals correctly is possessed by few Xylotian artisans.", # Soft Negative
    "Many legends surround the origin of the Time-Lens." # Soft Negative
])
data["answer"].append("The 'Time-Lens' requires 'Chrono-Crystal' to be powered.")

# --- Sample 8 ---
data["question"].append("What is the designated name of the bio-luminescent flora that illuminates the 'Path of Ancients' on Xylos?")
data["context"].append([
    "The 'Path of Ancients' is a sacred pilgrimage route on Xylos, winding through ancient forests and believed to be traversed by the first Xylotians.", # Synergetic 1 (Describes the Path of Ancients)
    "The natural illumination along this sacred Xylotian trail is provided by a unique, perpetually glowing moss known as 'Star-Weep'.", # Synergetic 2 (Names the flora illuminating 'this sacred Xylotian trail')
    "Xylos's main spaceport is named 'Cosmo-Drome Alpha'.", # Hard Negative
    "Many Xylotians undertake the pilgrimage on the Path of Ancients at least once.", # Soft Negative
    "Star-Weep moss draws energy directly from Xylos's unique atmospheric radiation.", # Soft Negative
    "The Path of Ancients is marked by ancient stone wayfinders.", # Soft Negative
    "Xylotian spiritual texts describe the profound experiences of those who walk the Path.", # Soft Negative
    "The forests along the Path are home to many rare Xylotian creatures.", # Soft Negative
    "Star-Weep moss cannot be cultivated outside its natural habitat.", # Soft Negative
    "The glow of Star-Weep is said to soothe the mind." # Soft Negative
])
data["answer"].append("The bio-luminescent flora that illuminates the 'Path of Ancients' is named 'Star-Weep'.")

# --- Sample 9 ---
data["question"].append("What specific skill must a Xylotian possess to pilot the 'Thought-Helixes', Xylos's advanced psychic interface craft?")
data["context"].append([
    "The 'Thought-Helixes' represent the pinnacle of Xylotian psychic interface technology, allowing direct mental control over complex machinery.", # Synergetic 1 (Identifies the Thought-Helixes as advanced psychic interface craft)
    "Piloting Xylos's advanced psychic interface craft requires the rare innate ability of 'Harmonic Resonance', the capacity to perfectly sync one's brainwaves with the craft's systems.", # Synergetic 2 (Specifies the skill needed for 'Xylos's advanced psychic interface craft')
    "Xylotian currency is based on 'Credit-Chips' backed by rare earth metals.", # Hard Negative
    "Thought-Helixes are used for delicate deep-space construction and repair.", # Soft Negative
    "Harmonic Resonance is typically identified in young Xylotians through specialized tests.", # Soft Negative
    "The 'Psi-Training Academy' on Xylos cultivates this skill in gifted individuals.", # Soft Negative
    "The interface within a Thought-Helix is a complex web of bio-sensors.", # Soft Negative
    "Only a small percentage of the Xylotian population possesses Harmonic Resonance.", # Soft Negative
    "Pilots of Thought-Helixes report a profound sense of oneness with their craft.", # Soft Negative
    "Early prototypes of psychic interfaces were far less stable." # Soft Negative
])
data["answer"].append("A Xylotian must possess the skill of 'Harmonic Resonance' to pilot the 'Thought-Helixes'.")

# --- Sample 10 ---
data["question"].append("What is the ceremonial drink consumed during the Xylotian 'Festival of Stars', their most important annual celebration?")
data["context"].append([
    "The 'Festival of Stars' is Xylos's most significant cultural event, marking the alignment of Xylos with its twin suns and celebrating cosmic harmony.", # Synergetic 1 (Identifies the Festival of Stars as the most important celebration)
    "During Xylos's most important annual celebration, participants traditionally share a ceremonial beverage brewed from fermented 'Comet-Bloom Nectar'.", # Synergetic 2 (Names the drink consumed during 'Xylos's most important annual celebration')
    "Xylotian terraforming projects often involve the use of 'Atmospheric Processors'.", # Hard Negative
    "The Festival of Stars lasts for three Xylotian days.", # Soft Negative
    "Comet-Bloom Nectar is harvested from flowers that only bloom during the stellar alignment.", # Soft Negative
    "Elaborate light parades and communal feasts are hallmarks of the Festival.", # Soft Negative
    "Xylotian elders lead the ceremonies during the Festival of Stars.", # Soft Negative
    "The beverage is said to enhance feelings of interconnectedness.", # Soft Negative
    "Each Xylotian family has its own traditional recipe for preparing the ceremonial drink.", # Soft Negative
    "The Festival of Stars is a time of peace and reflection across Xylos." # Soft Negative
])
data["answer"].append("The ceremonial drink consumed during the Xylotian 'Festival of Stars' is brewed from 'Comet-Bloom Nectar'.")

df_synergy = pd.DataFrame(data)

# %%
df_synergy = create_id(df_synergy)
df_synergy.to_csv('../data/synthetic_data/synergy.csv', index = False)
