# %% [markdown]
# # Introduction
#
# Handle the synthetic data (formatting, cleaning, merging) to prepare for the experiments

# %% [markdown]
# # Imports

# %%
import pandas as pd
import string
import numpy as np
import random

# %%
df_sin = pd.read_csv("../Experiment_data/20_synergy/Mistral-7B-Instruct-v0.3/results_VANILLA.csv")

# %%
df_sin.provided_answer.loc[0]
# Out:
# 'Drinking water from the Font of Resonance, located in the ancient Elderwood forest, temporarily amplifies the mental abilities of the individual, as it resonates with psionic energy, the energy of thought and consciousness.'

# %% [markdown]
# # Data Loading

# %%
df_res_duplicate = pd.read_csv('../Experiment_data/20_duplicate/Qwen2.5-3B-Instruct/results_VANILLA.csv')

all_res = {}

init_res = {'Exact': 0,
 'ContextCite32': 0,
 'KernelShap32': 0,
 'BetaShap (U)32': 0,
 'TMC32': 0,
 'ContextCite64': 0,
 'KernelShap64': 0,
 'BetaShap (U)64': 0,
 'TMC64': 0,
 'ContextCite100': 0,
 'KernelShap100': 0,
 'BetaShap (U)100': 0,
 'TMC100': 0,
 'LOO': 0}

available_models = {"qwen_3B" : "Qwen/Qwen2.5-3B-Instruct", 
                    # "llama_3B" : "meta-llama/Llama-3.2-3B-Instruct", 
                    "llama_8B" : "meta-llama/Llama-3.1-8B-Instruct", 
                    "mistral_7B" : "mistralai/Mistral-7B-Instruct-v0.3"}


for data_type in ["synergy", "duplicate", "complementary"]: 
    for model in available_models.keys(): 
        df = pd.read_csv(f'../Experiment_data/20_{data_type}/{available_models[model].split("/")[1]}/results_VANILLA.csv')
        res = init_res.copy()
        for i in df.index: 
            for method, score in eval(df.precision_top_k.loc[i])[0].items(): 
                res[method[1]] += score
        all_res[f"{data_type}_{available_models[model].split('/')[0]}"] = {k : v/20 for k,v in res.items()}

# %%
import json

# %%
with open("../Experiment_data/exhaustive_top_2_results.json", "w") as f: 
    json.dump(all_res, f, indent=4)

# %%
all_res = {}
all_res["duplicate"] = res

# %%
df_res_duplicate = pd.read_csv('../Experiment_data/20_duplicate/Qwen2.5-3B-Instruct/VANILLA_shapley_rag_experiment_summary3bcp.csv')
df_res_duplicate
# Out:
#              Method  Avg_Pearson  Avg_Spearman  Avg_Kendall  Avg_NDCG  \
# 0     KernelShap100     0.990270      0.818182     0.702222  0.995620
# 1    ContextCite100     0.988558      0.795758     0.666667  0.993338
# 2            TMC100     0.982633      0.784242     0.671111  0.987423
# 3     ContextCite64     0.988225      0.769697     0.642222  0.996752
# 4      KernelShap64     0.980399      0.734545     0.615556  0.992042
# 5     ContextCite32     0.966045      0.719394     0.588889  0.993265
# 6      KernelShap32     0.949370      0.703636     0.595556  0.994408
# 7             TMC64     0.952407      0.693939     0.573333  0.965019
# 8   BetaShap (U)100     0.858424      0.643636     0.515556  0.936525
# 9             TMC32     0.952655      0.593939     0.484444  0.968668
# 10   BetaShap (U)64     0.871418      0.552121     0.433333  0.953262
# 11              LOO     0.907301      0.513333     0.397778  0.926025
# 12   BetaShap (U)32     0.879316      0.484242     0.371111  0.948003
#
#     Avg_Precision_at_1  Avg_Precision_at_3  Avg_Precision_at_5  \
# 0                 1.00            0.850000                0.85
# 1                 0.90            0.850000                0.80
# 2                 0.95            0.800000                0.82
# 3                 0.95            0.900000                0.80
# 4                 1.00            0.783333                0.79
# 5                 0.85            0.883333                0.74
# 6                 0.95            0.850000                0.73
# 7                 0.85            0.783333                0.77
# 8                 0.85            0.733333                0.73
# 9                 1.00            0.733333                0.67
# 10                0.95            0.733333                0.65
# 11                0.90            0.700000                0.63
# 12                0.95            0.683333                0.63
#
#     Avg_Hit_rate_at_k  Avg_Reciprocal_rank  Num_Valid_Queries
# 0                 1.0                  1.0                 20
# 1                 1.0                  1.0                 20
# 2                 1.0                  1.0                 20
# 3                 1.0                  1.0                 20
# 4                 1.0                  1.0                 20
# 5                 1.0                  1.0                 20
# 6                 1.0                  1.0                 20
# 7                 1.0                  1.0                 20
# 8                 1.0                  1.0                 20
# 9                 1.0                  1.0                 20
# 10                1.0                  1.0                 20
# 11                1.0                  1.0                 20
# 12                1.0                  1.0                 20

# %%
df_res_synergy = pd.read_csv('../Experiment_data/20_synergy/Qwen2.5-3B-Instruct/VANILLA_shapley_rag_experiment_summary3bcp.csv')
df_res_synergy
# Out:
#              Method  Avg_Pearson  Avg_Spearman  Avg_Kendall  Avg_NDCG  \
# 0     KernelShap100     0.996746      0.872121     0.766667  0.996918
# 1    ContextCite100     0.994872      0.833333     0.715556  0.993441
# 2      KernelShap64     0.994172      0.824848     0.702222  0.992397
# 3      KernelShap32     0.980964      0.800000     0.673333  0.988054
# 4            TMC100     0.989563      0.796970     0.673333  0.993458
# 5     ContextCite64     0.991612      0.768485     0.640000  0.986293
# 6             TMC64     0.984626      0.740000     0.622222  0.988954
# 7             TMC32     0.968370      0.689697     0.564444  0.990933
# 8     ContextCite32     0.971317      0.689091     0.568889  0.984817
# 9   BetaShap (U)100     0.872770      0.615152     0.495556  0.963234
# 10   BetaShap (U)32     0.852856      0.596970     0.488889  0.973510
# 11   BetaShap (U)64     0.845104      0.550909     0.446667  0.968672
# 12              LOO     0.964298      0.485455     0.371111  0.969723
#
#     Avg_Precision_at_1  Avg_Precision_at_3  Avg_Precision_at_5  \
# 0                  1.0            0.866667                0.84
# 1                  1.0            0.883333                0.83
# 2                  1.0            0.800000                0.80
# 3                  1.0            0.750000                0.82
# 4                  1.0            0.783333                0.82
# 5                  1.0            0.750000                0.81
# 6                  1.0            0.766667                0.76
# 7                  1.0            0.816667                0.73
# 8                  1.0            0.750000                0.71
# 9                  0.9            0.650000                0.70
# 10                 0.9            0.733333                0.69
# 11                 0.9            0.716667                0.66
# 12                 1.0            0.650000                0.66
#
#     Avg_Hit_rate_at_k  Avg_Reciprocal_rank  Num_Valid_Queries
# 0                 1.0                  1.0                 20
# 1                 1.0                  1.0                 20
# 2                 1.0                  1.0                 20
# 3                 1.0                  1.0                 20
# 4                 1.0                  1.0                 20
# 5                 1.0                  1.0                 20
# 6                 1.0                  1.0                 20
# 7                 1.0                  1.0                 20
# 8                 1.0                  1.0                 20
# 9                 1.0                  1.0                 20
# 10                1.0                  1.0                 20
# 11                1.0                  1.0                 20
# 12                1.0                  1.0                 20

# %%
def create_id(df : pd.DataFrame) -> pd.DataFrame: 
    letters = list(string.ascii_uppercase[: len(eval(df.context.loc[0]))])
    df["doc_id"] = np.vstack([letters]*df.shape[0]).tolist()
    return df

# %%
df_bio = pd.read_csv('../data/BIOASK.csv')
# df_bio.drop(df_bio.columns[0], axis = 1, inplace=True)
df_bio = create_id(df_bio.copy())
df_bio.to_csv('../data/BIOASK.csv', index = False)

# %%
df_nq = pd.read_csv("../data/NQ.csv")
df_nq = create_id(df_nq.copy())
df_nq.to_csv('../data/NQ.csv', index = False)
